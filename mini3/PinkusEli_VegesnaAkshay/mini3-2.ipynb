# %%
import os
import numpy as np
from IPython.display import HTML
import re
from HMM import unsupervised_HMM
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    sample_sentence,
    visualize_sparsities,
    animate_emission,
    sample_sonnet_line,
    obs_map_reverser
)

# %%
def is_number(s):
    try:
        int(s)
        return True
    except ValueError:
        return False

# %% [markdown]
# # Working On Ryhming dictinoary

# %%
f2 = open('data/shakespeare.txt', 'r')

# %%
f2 = open('data/shakespeare.txt', 'r')
sonnets = []
sonnet = []
while True:
    line = f2.readline()
    if line == '':
        break
        
    if is_number(line):
        sonnets.append(sonnet)
        sonnet = []
    else:
        sonnet.append(line)
sonnets.append(sonnet)    
sonnets = sonnets[1:]

# for sonnet in sonnets:
#     for i in range(len(sonnet)):
#         if i != len(sonnet) - 1:
#             sonnet[i] = sonnet[i][:-2]
#         else:
#             sonnet[i] = sonnet[i][:-1]

sonnets = [[line for line in sonnet if line != []] for sonnet in sonnets]
sonnets = [[line.split() for line in sonnet] for sonnet in sonnets]
sonnets = [[line for line in sonnet if line != []] for sonnet in sonnets]
sonnets = [[line for line in sonnet] for sonnet in sonnets if len(sonnet) == 14]

for s in range(len(sonnets)):
    for l in range(len(sonnets[s])):
        if sonnets[s][l][-1][-1] in [',', '.', '?', '!', ':', '\'' ,')', ';']:
            sonnets[s][l][-1] = sonnets[s][l][-1][:-1]
            
for s in range(len(sonnets)):
    for l in range(len(sonnets[s])):
        if sonnets[s][l][-1][-1] in [',', '.', '?', '!', ':','\'', ')', ';']:
            sonnets[s][l][-1] = sonnets[s][l][-1][:-1]

# %%
r_dic = dict()
for sonnet in sonnets:
    for i in range(len(sonnet)):
        end = sonnet[i][-1]
        if not (end in r_dic.keys()):
                r_dic[end] = []
        
        
        
        
        
    r_dic[sonnet[0][-1]].append(sonnet[2][-1])
    r_dic[sonnet[2][-1]].append(sonnet[0][-1])

    r_dic[sonnet[1][-1]].append(sonnet[3][-1])
    r_dic[sonnet[3][-1]].append(sonnet[1][-1])
    
    
    
    r_dic[sonnet[4][-1]].append(sonnet[6][-1])
    r_dic[sonnet[6][-1]].append(sonnet[4][-1])
    
    r_dic[sonnet[5][-1]].append(sonnet[7][-1])
    r_dic[sonnet[7][-1]].append(sonnet[5][-1])
    
    
    r_dic[sonnet[8][-1]].append(sonnet[10][-1])
    r_dic[sonnet[10][-1]].append(sonnet[8][-1])
    
    r_dic[sonnet[9][-1]].append(sonnet[11][-1])
    r_dic[sonnet[11][-1]].append(sonnet[9][-1])
    
    r_dic[sonnet[12][-1]].append(sonnet[13][-1])
    r_dic[sonnet[13][-1]].append(sonnet[12][-1])

for key in r_dic.keys():
    r_dic[key] = list(set(r_dic[key]))
r_dic
# Out:
# {'increase': ['decease', 'decrease', 'cease'],
#  'die': ['memory', 'thereby', 'eye', 'dignity', 'lie'],
#  'decease': ['lease', 'increase'],
#  'memory': ['fortify', 'die', 'eternity', 'masonry', 'sky'],
#  'eyes': ['arise',
#   'spies',
#   'lies',
#   'devise',
#   'prophecies',
#   'cries',
#   'despise'],
#  'fuel': ['cruel'],
#  'lies': ['subtleties', 'eyes'],
#  'cruel': ['fuel', 'jewel'],
#  'ornament': ['content'],
#  'spring': ['sing', 'niggarding', 'king', 'thing'],
#  'content': ['spent', 'ornament'],
#  'niggarding': ['spring'],
#  'be': ['thee', 'decree', 'I', 'idolatry', 'me', 'see'],
#  'thee': ['melancholy',
#   'thee',
#   'usury',
#   'free',
#   'posterity',
#   'be',
#   'me',
#   'see'],
#  'brow': ['allow', 'mow', 'now'],
#  'field': ['held'],
#  'now': ['how', 'bow', 'brow', 'bough'],
#  'held': ['field', 'stelled'],
#  'days': ['lays', 'praise', 'decays'],
#  'praise': ['days'],
#  'use': ['muse', 'excuse', 'abuse'],
#  'mine': ['thine', 'define', 'line', 'shine'],
#  'excuse': ['use'],
#  'thine': ['divine', 'shine', 'mine'],
#  'old': ['cold', 'told', 'behold'],
#  'cold': ['behold', 'uphold', 'old'],
#  'viewest': ['renewest'],
#  'another': ['mother'],
#  'renewest': ['viewest'],
#  'mother': ['another'],
#  'womb': ['tomb'],
#  'husbandry': ['posterity'],
#  'tomb': ['come', 'dumb', 'womb'],
#  'posterity': ['enmity', 'thee', 'husbandry'],
#  'prime': ['time'],
#  'see': ['constancy', 'thee', 'be'],
#  'time': ['prime', 'rhyme', 'crime'],
#  'spend': ['end', 'friend', 'lend', 'tend'],
#  'legacy': ['free'],
#  'lend': ['friend', 'spend', 'tend'],
#  'free': ['thee', 'me', 'legacy'],
#  'abuse': ['use'],
#  'give': ['live'],
#  'live': ['achieve', 'give'],
#  'alone': ['groan', 'one', 'anon', 'prone', 'gone'],
#  'deceive': ['leave'],
#  'gone': ['alone', 'moan', 'on'],
#  'leave': ['deceive'],
#  'frame': ['same'],
#  'dwell': ['bell', 'tell', 'excel'],
#  'same': ['frame', 'name'],
#  'excel': ['dwell'],
#  'on': ['gone', 'groan'],
#  'there': ['near', 'dear', 'forbear', 'everywhere', 'where'],
#  'where': ['clear', 'appear', 'there'],
#  'left': ['bereft'],
#  'glass': ['was'],
#  'bereft': ['left'],
#  'was': ['glass', 'pass'],
#  'meet': ['sweet'],
#  'sweet': ['meet', 'greet'],
#  'deface': ['place'],
#  'distilled': ['self-killed'],
#  'place': ['grace', 'face', 'deface', 'case'],
#  'self-killed': ['distilled'],
#  'usury': ['thee'],
#  'loan': ['one'],
#  'one': ['loan', 'alone', 'none'],
#  'art': ['heart', 'convert', 'part', 'depart'],
#  'depart': ['heart', 'art'],
#  'fair': ['despair', 'repair', 'heir', 'air'],
#  'heir': ['fair'],
#  'light': ['bright', 'might', 'sight', 'fight'],
#  'eye': ['history', 'remedy', 'majesty', 'gravity', 'die', 'alchemy', 'lie'],
#  'sight': ['light', 'night', 'might', 'right', 'aright', 'delight'],
#  'majesty': ['fly', 'eye'],
#  'hill': ['still'],
#  'age': ['pilgrimage', 'page', 'equipage', 'presage', 'rage'],
#  'still': ['Will', 'ill', 'skill', 'quill', 'will', 'hill'],
#  'pilgrimage': ['age'],
#  'car': ['are'],
#  'day': ['May', 'way', 're-survey', 'stay', 'sway', 'decay', 'repay', 'away'],
#  'are': ['prepare', 'compare', 'care', 'rare', 'car'],
#  'way': ['decay', 'say', 'day', 'stay'],
#  'noon': ['son'],
#  'son': ['won', 'noon'],
#  'sadly': ['gladly'],
#  'joy': ['annoy'],
#  'gladly': ['sadly'],
#  'annoy': ['joy'],
#  'sounds': ['confounds'],
#  'ear': ['bear'],
#  'confounds': ['sounds'],
#  'bear': ['wear', 'were', 'appear', 'swear', 'ear'],
#  'ordering': ['sing'],
#  'sing': ['spring', 'wing', 'prefiguring', 'bring', 'ordering'],
#  'none': ['one', 'stone'],
#  'life': ['knife', 'strife', 'wife'],
#  'wife': ['life'],
#  'weep': ['keep'],
#  'behind': ['mind', 'kind'],
#  'keep': ['weep', 'asleep'],
#  'mind': ['blind', 'find', 'behind', 'kind'],
#  'it': ['it', 'sit'],
#  'end': ['depend', 'contend', 'friend', 'spend', 'fiend'],
#  'sits': ['commits'],
#  'commits': ['befits', 'sits'],
#  'any': ['many'],
#  'unprovident': ['evident'],
#  'many': ['any'],
#  'evident': ['unprovident'],
#  'hate': ['ruinate', 'debate', 'accumulate', 'state', 'advocate'],
#  'conspire': ['desire'],
#  'ruinate': ['hate'],
#  'desire': ['fire', 'conspire', 'admire', 'require'],
#  'love': ['remove', 'move', 'prove', 'approve', 'above'],
#  'kind': ['confined', 'bind', 'mind', 'behind'],
#  'prove': ['Love', 'love'],
#  'me': ['thee', 'free', 'fee', 'be', 'ye'],
#  "grow'st": ["ow'st", "bestow'st"],
#  'departest': ['convertest'],
#  "bestow'st": ["grow'st"],
#  'convertest': ['departest'],
#  'decay': ['day', 'way', 'stay', 'clay', 'say', 'away', 'survey'],
#  'cease': ['increase'],
#  'away': ['day', 'betray', 'gay', 'stay', 'decay', 'play'],
#  'store': ['shore', 'yore', 'more'],
#  'perish': ['cherish'],
#  'more': ['score', 'store', 'before', 'abhor'],
#  'cherish': ['perish'],
#  'thereby': ['die'],
#  'night': ['plight', 'write', 'bright', 'sight', 'delight', 'white'],
#  'white': ['delight', 'night'],
#  'leaves': ['sheaves'],
#  'herd': ['beard'],
#  'sheaves': ['leaves'],
#  'beard': ['herd'],
#  'make': ['forsake', 'take', 'sake'],
#  'go': ['wilful-slow', 'grow', 'know'],
#  'forsake': ['make'],
#  'grow': ['show', 'so', 'go'],
#  'defence': ['hence', 'offence'],
#  'hence': ['defence'],
#  'prepare': ['are'],
#  'lease': ['excess', 'decease'],
#  'were': ['bear', 'near'],
#  'uphold': ['cold'],
#  'know': ['show', 'go', 'slow', 'so', 'woe'],
#  'so': ['no', 'know', 'show', 'grow', 'woe'],
#  'pluck': ['luck'],
#  'astronomy': ['quality'],
#  'luck': ['pluck'],
#  'quality': ['astronomy'],
#  'tell': ['hell', 'dwell', 'well', 'smell'],
#  'wind': ['find'],
#  'well': ['hell', 'sell', 'tell'],
#  'find': ['wind', 'mind', 'blind'],
#  'derive': ['thrive'],
#  'thrive': ['derive'],
#  'convert': ['art'],
#  'prognosticate': ['date'],
#  'date': ['prognosticate', 'expiate', 'invocate', 'temperate'],
#  'grows': ['shows', 'those'],
#  'moment': ['comment'],
#  'shows': ['grows', 'foes'],
#  'comment': ['moment'],
#  'sky': ['memory'],
#  'decrease': ['increase'],
#  'stay': ['decay', 'away', 'way', 'day'],
#  'you': ['untrue', 'threw', 'new', 'true', 'adieu', 'grew'],
#  'new': ['view', 'true', 'you'],
#  'Time': ['rhyme', 'crime'],
#  'rhyme': ['time', 'Time'],
#  'hours': ['flowers', 'showers'],
#  'unset': ['counterfeit'],
#  'flowers': ['hours'],
#  'counterfeit': ['set', 'unset'],
#  'repair': ['fair'],
#  'pen': ['men', 'again', 'Amen'],
#  'men': ['pen', 'then'],
#  'skill': ['ill', 'still'],
#  'come': ['doom', 'tomb', 'sum'],
#  'deserts': ['parts'],
#  'parts': ['deserts', 'hearts'],
#  'graces': ['faces'],
#  'faces': ['graces'],
#  'tongue': ['young', 'wronk', 'song', 'wrong'],
#  'rage': ['stage', 'age'],
#  'song': ['long', 'tongue'],
#  'temperate': ['date'],
#  'May': ['day'],
#  'shines': ['declines'],
#  'dimmed': ['untrimmed'],
#  'declines': ['shines'],
#  'untrimmed': ['dimmed'],
#  'fade': ['made', 'shade'],
#  "ow'st": ["grow'st"],
#  'shade': ['fade', 'made'],
#  'paws': ['jaws'],
#  'brood': ['blood'],
#  'jaws': ['paws'],
#  'blood': ['good', 'brood'],
#  "fleet'st": ['sweets'],
#  'sweets': ["fleet'st"],
#  'crime': ['time', 'Time'],
#  'allow': ['brow'],
#  'wrong': ['young', 'tongue', 'belong'],
#  'young': ['tongue', 'wrong'],
#  'painted': ['acquainted'],
#  'passion': ['fashion'],
#  'acquainted': ['painted', 'attainted'],
#  'fashion': ['passion'],
#  'rolling': ['controlling'],
#  'gazeth': ['amazeth'],
#  'controlling': ['rolling'],
#  'amazeth': ['gazeth'],
#  'created': ['defeated'],
#  'a-doting': ['nothing'],
#  'defeated': ['created'],
#  'nothing': ['a-doting'],
#  'pleasure': ['leisure', 'measure', 'treasure'],
#  'treasure': ['pleasure'],
#  'muse': ['use'],
#  'verse': ['rehearse', 'inhearse', 'disperse'],
#  'rehearse': ['verse'],
#  'compare': ['rare', 'are'],
#  'gems': ['hems'],
#  'rare': ['care', 'compare', 'are'],
#  'hems': ['gems'],
#  'write': ['bright', 'might', 'quite', 'night'],
#  'bright': ['light', 'might', 'write', 'night'],
#  'air': ['fair'],
#  'sell': ['well'],
#  'behold': ['cold', 'old', 'bold'],
#  'expiate': ['date'],
#  'heart': ['art', 'part', 'depart'],
#  'wary': ['chary'],
#  'will': ['ill', 'still'],
#  'chary': ['wary'],
#  'ill': ['skill', 'will', 'fill', 'still'],
#  'slain': ['pain', 'again'],
#  'again': ['pen', 'slain', 'stain'],
#  'stage': ['rage'],
#  'part': ['heart', 'art', 'desert'],
#  'say': ['lay', 'way', 'pay', 'they', 'decay'],
#  'rite': ['might'],
#  'might': ['light', 'spite', 'write', 'rite', 'appetite', 'bright', 'sight'],
#  'eloquence': ['recompense'],
#  'breast': ['guest', 'expressed', 'chest', 'best'],
#  'recompense': ['eloquence'],
#  'expressed': ['unrest', 'breast', 'best'],
#  'writ': ['wit'],
#  'wit': ['writ', 'sit', 'knit'],
#  'stelled': ['held'],
#  'done': ['sun'],
#  'sun': ['dun', 'done'],
#  'stars': ['bars'],
#  'boast': ['costs', 'ghost', 'most'],
#  'bars': ['stars'],
#  'most': ['boast', 'lost'],
#  'spread': ['buried'],
#  'buried': ['dead', 'spread'],
#  'fight': ['light', 'quite'],
#  'foiled': ['toiled'],
#  'quite': ['recite', 'write', 'fight'],
#  'toiled': ['foiled'],
#  'beloved': ['removed'],
#  'removed': ['beloved'],
#  'vassalage': ['embassage'],
#  'knit': ['wit'],
#  'embassage': ['vassalage'],
#  'moving': ['loving'],
#  'aspect': ['respect'],
#  'loving': ['moving', 'reproving'],
#  'respect': ['defect', 'effect', 'aspect'],
#  'bed': ['head'],
#  'tired': ['expired'],
#  'head': ['bed', 'dead', 'fled', 'red'],
#  'expired': ['tired'],
#  'abide': ['wide', 'slide'],
#  'wide': ['belied', 'abide'],
#  'view': ['new', 'true', 'due'],
#  'plight': ['night'],
#  'rest': ['oppressed', 'west', 'best'],
#  'oppressed': ['rest'],
#  'reign': ['maintain', 'complain'],
#  'complain': ['reign'],
#  'heaven': ['even'],
#  'even': ['heaven'],
#  'longer': ['stronger'],
#  'stronger': ['longer'],
#  'state': ['gait', 'anticipate', 'fate', 'translate', 'gate', 'hate'],
#  'cries': ['eyes'],
#  'fate': ['state'],
#  'hope': ['scope'],
#  'possessed': ['least'],
#  'scope': ['hope'],
#  'least': ['possessed'],
#  'despising': ['arising'],
#  'arising': ['despising'],
#  'gate': ['state'],
#  'brings': ['kings'],
#  'kings': ['things', 'brings'],
#  'thought': ['wrought', 'brought', 'nought', 'sought'],
#  'past': ['haste', 'waste'],
#  'sought': ['thought'],
#  'waste': ['past', 'taste'],
#  'flow': ['woe'],
#  'woe': ['know', 'slow', 'overthrow', 'so', 'flow'],
#  'foregone': ['moan'],
#  "o'er": ['before'],
#  'moan': ['upon', 'gone', 'foregone'],
#  'before': ['shore', "o'er", 'more'],
#  'friend': ['end', 'lend', 'spend', 'fiend'],
#  'hearts': ['parts'],
#  'dead': ['unbred',
#   "o'er-read",
#   'head',
#   'astonished',
#   'remembered',
#   'bred',
#   'fled',
#   'buried'],
#  'tear': ['appear'],
#  'appear': ['bear', 'year', 'tear', 'where'],
#  'lie': ['qualify', 'deny', 'eye', 'die', 'I', 'defy', 'why', 'by'],
#  'cover': ['lover'],
#  're-survey': ['day'],
#  'lover': ['cover'],
#  'brought': ['thought'],
#  'equipage': ['age'],
#  'seen': ['green', 'queen', 'been'],
#  'green': ['seen'],
#  'alchemy': ['flattery', 'eye'],
#  'ride': ['hide', 'tied', 'pride'],
#  'face': ['place', 'chase', 'disgrace', 'grace'],
#  'hide': ['ride', 'denied', 'side', 'pride'],
#  'disgrace': ['face'],
#  'shine': ['thine', 'mine'],
#  'disdaineth': ['staineth'],
#  'staineth': ['disdaineth'],
#  'cloak': ['smoke'],
#  'smoke': ['cloak'],
#  'break': ['speak'],
#  'speak': ['break'],
#  'grief': ['relief', 'thief', 'chief'],
#  'loss': ['dross', 'cross'],
#  'relief': ['grief'],
#  'cross': ['after-loss', 'loss'],
#  'sheds': ['deeds'],
#  'deeds': ['exceeds', 'sheds', 'weeds', 'breeds', 'proceeds'],
#  'mud': ['bud'],
#  'bud': ['mud'],
#  'this': ['is', 'kiss', 'amiss'],
#  'amiss': ['is', 'this'],
#  'sense': ['commence', 'dispense'],
#  'advocate': ['hate'],
#  'commence': ['sense'],
#  'twain': ['remain', 'gain'],
#  'remain': ['twain', 'brain'],
#  'spite': ['might', 'delight'],
#  'effect': ['respect'],
#  'delight': ['spite', 'night', 'sight', 'white'],
#  'shame': ['blame', 'name'],
#  'name': ['same', 'fame', 'shame'],
#  'sort': ['report'],
#  'report': ['sort', 'short', 'sport'],
#  'youth': ['truth'],
#  'truth': ['youth'],
#  'sit': ['it', 'wit'],
#  'despised': ['sufficed'],
#  'sufficed': ['despised'],
#  'invent': ['argument', 'excellent'],
#  'excellent': ['invent'],
#  'worth': ['forth'],
#  'invocate': ['date'],
#  'forth': ['worth'],
#  'bring': ['sing'],
#  'all': ['call'],
#  'call': ['fall', 'all'],
#  'receivest': ['deceivest'],
#  'usest': ['refusest'],
#  'deceivest': ['receivest'],
#  'refusest': ['usest'],
#  'thief': ['grief'],
#  'poverty': ['injury'],
#  'injury': ['poverty', 'liberty'],
#  'foes': ['shows', 'knows'],
#  'befits': ['commits'],
#  'won': ['son'],
#  'assailed': ['prevailed'],
#  'prevailed': ['assailed'],
#  'forbear': ['there'],
#  'dearly': ['nearly'],
#  'chief': ['grief'],
#  'nearly': ['dearly'],
#  'ye': ['me'],
#  'her': ['her'],
#  'gain': ['pain', 'main', 'twain'],
#  'unrespected': ['directed'],
#  'directed': ['unrespected'],
#  'show': ['owe', 'know', 'grow', 'slow', 'so'],
#  'made': ['jade', 'fade', 'shade'],
#  'stand': ['land', 'hand'],
#  'land': ['stand'],
#  'wrought': ['thought'],
#  'slow': ['know', 'show', 'woe'],
#  'fire': ['expire', 'desire'],
#  'slide': ['abide'],
#  'melancholy': ['thee'],
#  'recured': ['assured'],
#  'assured': ['cured', 'endured', 'recured'],
#  'glad': ['sad'],
#  'sad': ['glad'],
#  'war': ['bar'],
#  'bar': ['war'],
#  'right': ['sight'],
#  'deny': ['lie'],
#  'impanelled': ['determined'],
#  'determined': ['impanelled'],
#  'took': ['look'],
#  'other': ['smother'],
#  'look': ['book', 'took'],
#  'smother': ['other'],
#  'feast': ['guest'],
#  'guest': ['feast', 'breast'],
#  'move': ['love'],
#  'thrust': ['trust'],
#  'trust': ['lust', 'unjust', 'thrust'],
#  'care': ['rare', 'are'],
#  'chest': ['special-blest', 'breast'],
#  'fear': ['dear'],
#  'dear': ['fear', 'there'],
#  'defects': ['respects'],
#  'sum': ['come'],
#  'respects': ['defects'],
#  'pass': ['was'],
#  'gravity': ['eye'],
#  'here': ['uprear'],
#  'desert': ['impart', 'part'],
#  'uprear': ['here'],
#  'laws': ['cause'],
#  'cause': ['laws'],
#  'groan': ['alone', 'on'],
#  'side': ['hide', 'pride'],
#  'offence': ['thence', 'defence'],
#  'speed': ['need'],
#  'thence': ['intelligence', 'offence'],
#  'need': ['exceed', 'speed'],
#  'pace': ['race'],
#  'race': ['pace'],
#  'jade': ['made'],
#  'wilful-slow': ['go'],
#  'key': ['survey'],
#  'survey': ['decay', 'key'],
#  'set': ['debt', 'counterfeit', 'carcanet'],
#  'carcanet': ['set'],
#  'special-blest': ['chest'],
#  'pride': ['ride', 'hide', 'beside', 'aside', 'eyed', 'side'],
#  'tend': ['lend', 'spend', 'mend'],
#  'year': ['everywhere', 'appear'],
#  'seem': ['deem', 'esteem'],
#  'deem': ['seem'],
#  'dye': ['wantonly'],
#  'roses': ['discloses'],
#  'wantonly': ['dye'],
#  'discloses': ['roses'],
#  'monuments': ['contents'],
#  'contents': ['monuments'],
#  'overturn': ['burn'],
#  'masonry': ['memory'],
#  'burn': ['overturn'],
#  'enmity': ['posterity'],
#  'room': ['doom'],
#  'doom': ['come', 'room'],
#  'arise': ['eyes'],
#  'said': ['allayed'],
#  'appetite': ['might'],
#  'allayed': ['said'],
#  'fill': ['ill', 'kill'],
#  'fulness': ['dulness'],
#  'kill': ["'Will", 'fill'],
#  'dulness': ['fulness'],
#  'require': ['desire'],
#  'hour': ['sour'],
#  'sour': ['hour'],
#  'adieu': ['you'],
#  'suppose': ['those'],
#  'nought': ['thought'],
#  'those': ['grows', 'rose', 'suppose'],
#  'slave': ['crave'],
#  'crave': ['slave'],
#  'leisure': ['pleasure'],
#  'beck': ['check'],
#  'liberty': ['injury'],
#  'check': ['beck'],
#  'strong': ['long', 'belong'],
#  'belong': ['wrong', 'strong'],
#  'hell': ['well', 'tell'],
#  'is': ['this', 'his', 'amiss', 'amis'],
#  'beguiled': ['child'],
#  'amis': ['is'],
#  'child': ['beguiled'],
#  'book': ["o'erlook", 'look'],
#  'they': ['say'],
#  'shore': ['store', 'before'],
#  'contend': ['end'],
#  'crowned': ['confound'],
#  'confound': ['crowned'],
#  'mow': ['brow'],
#  'hand': ['stand', 'brand'],
#  'open': ['broken'],
#  'broken': ['open'],
#  'pry': ['jealousy'],
#  'jealousy': ['pry'],
#  'great': ['defeat'],
#  'awake': ['sake'],
#  'defeat': ['great'],
#  'sake': ['awake', 'partake', 'take', 'make'],
#  'elsewhere': ['near'],
#  'near': ['elsewhere', 'there', 'were', 'cheer'],
#  'remedy': ['by', 'eye'],
#  'account': ['surmount'],
#  'define': ['mine'],
#  'surmount': ['account'],
#  'indeed': ['read'],
#  'antiquity': ['iniquity'],
#  'read': ['indeed'],
#  'iniquity': ['antiquity'],
#  "o'erworn": ['morn'],
#  'morn': ["o'erworn"],
#  'king': ['spring'],
#  'fortify': ['memory'],
#  'knife': ['life'],
#  'defaced': ['down-rased'],
#  'down-rased': ['defaced'],
#  'main': ['gain'],
#  'State': ['ruminate'],
#  'ruminate': ['State'],
#  'choose': ['lose'],
#  'lose': ['choose'],
#  'sea': ['plea'],
#  'power': ['bower', 'flower'],
#  'plea': ['sea'],
#  'flower': ['power'],
#  'out': ['stout', 'doubt', 'about'],
#  'stout': ['out'],
#  'decays': ['days'],
#  'alack': ['back'],
#  'hid': ['forbid'],
#  'back': ['alack'],
#  'forbid': ['hid'],
#  'cry': ['jollity'],
#  'born': ['forsworn', 'outworn'],
#  'jollity': ['cry'],
#  'forsworn': ['scorn', 'born', 'torn'],
#  'misplaced': ['disgraced'],
#  'strumpeted': ['disabled'],
#  'disgraced': ['misplaced'],
#  'disabled': ['strumpeted'],
#  'authority': ['simplicity'],
#  'simplicity': ['authority'],
#  'impiety': ['society'],
#  'achieve': ['live'],
#  'society': ['impiety'],
#  'cheek': ['seek'],
#  'hue': ['true', 'grew', 'anew'],
#  'seek': ['cheek'],
#  'true': ['you', 'new', 'view', 'hue', 'anew'],
#  'veins': ['gains'],
#  'his': ['is'],
#  'gains': ['veins'],
#  'had': ['mad', 'bad'],
#  'bad': ['mad', 'had'],
#  'outworn': ['born'],
#  'gay': ['away', 'array'],
#  'yore': ['store'],
#  'mend': ['commend', 'tend'],
#  'due': ['view', 'review'],
#  'commend': ['mend'],
#  'own': ['shown'],
#  'shown': ['own'],
#  'weeds': ['deeds'],
#  'defect': ['suspect', 'respect'],
#  'suspect': ['defect'],
#  'approve': ['love'],
#  'charged': ['enlarged'],
#  'enlarged': ['charged'],
#  'owe': ['show'],
#  'bell': ['dwell'],
#  'fled': ['dead', 'head'],
#  'not': ['plot', 'forgot', 'blot'],
#  'forgot': ['not'],
#  'clay': ['decay'],
#  'recite': ['quite'],
#  'I': ['be', 'lie'],
#  'impart': ['desert'],
#  'untrue': ['you'],
#  'hang': ['sang'],
#  'sang': ['hang'],
#  'west': ['east', 'rest'],
#  'expire': ['fire'],
#  'by': ['remedy', 'lie'],
#  'long': ['song', 'strong'],
#  'arrest': ['interest'],
#  'interest': ['arrest'],
#  'review': ['due'],
#  'remembered': ['dead', 'tendered'],
#  'contains': ['remains'],
#  'remains': ['contains'],
#  'ground': ['found', 'sound'],
#  'strife': ['life'],
#  'found': ['ground'],
#  'anon': ['alone'],
#  'change': ['strange'],
#  'aside': ['bide', 'pride'],
#  'strange': ['change'],
#  'weed': ['proceed'],
#  'proceed': ['weed'],
#  'argument': ['spent', 'invent'],
#  'spent': ['monument', 'content', 'argument', 'rent'],
#  'told': ['old'],
#  'wear': ['bear'],
#  'taste': ['last', 'waste'],
#  'eternity': ['memory', 'canopy'],
#  'contain': ['brain'],
#  'brain': ['remain', 'contain'],
#  'disperse': ['verse'],
#  'fly': ['majesty'],
#  'wing': ['sing'],
#  'compile': ['style'],
#  'style': ['compile'],
#  'advance': ['ignorance'],
#  'ignorance': ['advance'],
#  'aid': ['decayed'],
#  'grace': ['place', 'face'],
#  'decayed': ['aid'],
#  'word': ['afford'],
#  'afford': ['word'],
#  'pay': ['say'],
#  'fame': ['name'],
#  'afloat': ['boat'],
#  'boat': ['afloat'],
#  'rotten': ['forgotten'],
#  'take': ['sake', 'make'],
#  'forgotten': ['rotten'],
#  'have': ['grave'],
#  'grave': ['have'],
#  "o'er-read": ['dead'],
#  "o'erlook": ['book'],
#  'anew': ['hue', 'true'],
#  'devised': ['sympathized'],
#  'sympathized': ['devised'],
#  'used': ['abused'],
#  'abused': ['used'],
#  'exceed': ['need'],
#  'debt': ['set'],
#  'short': ['report'],
#  'impute': ['mute'],
#  'dumb': ['tomb'],
#  'mute': ['impute', 'fruit'],
#  'devise': ['eyes'],
#  'grew': ['hue', 'you'],
#  'glory': ['story'],
#  'story': ['glory'],
#  'clear': ['where'],
#  'curse': ['worse'],
#  'worse': ['curse'],
#  'compiled': ['filed'],
#  'quill': ['still'],
#  'filed': ['compiled'],
#  'words': ['affords'],
#  'Amen': ['pen'],
#  'affords': ['words'],
#  'inhearse': ['verse'],
#  'astonished': ['dead'],
#  'ghost': ['boast'],
#  'intelligence': ['thence'],
#  'line': ['mine'],
#  'possessing': ['releasing'],
#  'estimate': ['determinate'],
#  'releasing': ['possessing'],
#  'determinate': ['estimate'],
#  'granting': ['wanting'],
#  'deserving': ['swerving'],
#  'wanting': ['granting'],
#  'swerving': ['deserving'],
#  'knowing': ['growing'],
#  'mistaking': ['making'],
#  'growing': ['knowing'],
#  'making': ['mistaking'],
#  'flatter': ['matter'],
#  'matter': ['flatter'],
#  'scorn': ['forsworn'],
#  'attainted': ['acquainted'],
#  'too': ['do'],
#  'do': ['too'],
#  'fault': ['halt'],
#  'halt': ['fault'],
#  'wronk': ['tongue'],
#  'debate': ['hate'],
#  'bow': ['now'],
#  'after-loss': ['cross'],
#  'sorrow': ['morrow'],
#  'morrow': ['sorrow'],
#  'overthrow': ['woe'],
#  'last': ['taste'],
#  'force': ['horse'],
#  'horse': ['force'],
#  'measure': ['pleasure'],
#  'best': ['indigest', 'expressed', 'suppressed', 'rest', 'breast'],
#  'costs': ['boast'],
#  'wrongs': ['belongs'],
#  'belongs': ['wrongs'],
#  'depend': ['end'],
#  'blot': ['got', 'not'],
#  'history': ['eye'],
#  'decree': ['be'],
#  'stone': ['none'],
#  'expense': ['excellence'],
#  'excellence': ['expense', 'difference'],
#  'dignity': ['die'],
#  'rose': ['enclose', 'those'],
#  'enclose': ['rose'],
#  'sport': ['resort', 'report'],
#  'got': ['blot'],
#  'privilege': ['edge'],
#  'edge': ['privilege'],
#  'wantonness': ['less'],
#  'less': ['wantonness'],
#  'resort': ['sport'],
#  'queen': ['seen'],
#  'esteemed': ['deemed'],
#  'deemed': ['esteemed'],
#  'betray': ['away', 'may'],
#  'translate': ['state'],
#  'been': ['seen'],
#  'everywhere': ['year', 'there'],
#  'fruit': ['mute'],
#  'cheer': ['near'],
#  'trim': ['him'],
#  'thing': ['spring'],
#  'him': ['trim'],
#  'smell': ['tell'],
#  'play': ['away'],
#  'redeem': ['esteem'],
#  'esteem': ['redeem', 'seem'],
#  'amends': ['depends'],
#  'dyed': ['dignified'],
#  'depends': ['amends'],
#  'dignified': ['dyed'],
#  'fixed': ['intermixed'],
#  'lay': ['say'],
#  'intermixed': ['fixed'],
#  'how': ['now'],
#  'seeming': ['esteeming'],
#  'esteeming': ['seeming'],
#  'lays': ['days'],
#  'bough': ['now'],
#  'beside': ['pride'],
#  'eyed': ['pride'],
#  'turned': ['burned'],
#  'burned': ['turned'],
#  'perceived': ['deceived'],
#  'deceived': ['perceived'],
#  'unbred': ['dead'],
#  'idolatry': ['be'],
#  'confined': ['grind', 'kind'],
#  'difference': ['excellence'],
#  'wights': ['knights'],
#  'knights': ['wights'],
#  'prophecies': ['eyes'],
#  'prefiguring': ['sing'],
#  'soul': ['control'],
#  'control': ['soul'],
#  'endured': ['assured'],
#  'presage': ['age'],
#  'subscribes': ['tribes'],
#  'tribes': ['subscribes'],
#  'monument': ['spent'],
#  'character': ['register'],
#  'spirit': ['merit'],
#  'register': ['character'],
#  'merit': ['spirit'],
#  'divine': ['thine'],
#  'case': ['place'],
#  'page': ['age'],
#  'bred': ['dead'],
#  'qualify': ['lie'],
#  'ranged': ['exchanged'],
#  'exchanged': ['ranged'],
#  'stain': ['again'],
#  'reigned': ['stained'],
#  'stained': ['reigned'],
#  'good': ['blood'],
#  'above': ['love'],
#  'grind': ['confined'],
#  'chide': ['provide'],
#  'provide': ['chide'],
#  'breeds': ['deeds'],
#  'brand': ['hand'],
#  'subdued': ['renewed'],
#  'renewed': ['subdued'],
#  'drink': ['think'],
#  'infection': ['correction'],
#  'think': ['drink'],
#  'correction': ['infection'],
#  'strive': ['alive'],
#  'alive': ['strive'],
#  'dispense': ['sense'],
#  'about': ['out'],
#  'blind': ['find', 'mind'],
#  'latch': ['catch'],
#  'catch': ['dispatch', 'latch'],
#  'creature': ['feature'],
#  'feature': ['creature'],
#  'flattery': ['alchemy'],
#  'indigest': ['best'],
#  'resemble': ['assemble'],
#  'assemble': ['resemble'],
#  'seeing': ["'greeing", 'being'],
#  'up': ['cup'],
#  "'greeing": ['seeing'],
#  'cup': ['up'],
#  'sin': ['begin'],
#  'begin': ['sin'],
#  'dearer': ['clearer'],
#  'why': ['lie'],
#  'clearer': ['dearer'],
#  'accidents': ['intents'],
#  'intents': ['accidents'],
#  'things': ['kings'],
#  'tyranny': ['incertainty'],
#  'incertainty': ['tyranny'],
#  'minds': ['winds', 'finds'],
#  'finds': ['minds'],
#  'remove': ['love'],
#  'mark': ['bark'],
#  'shaken': ['taken'],
#  'bark': ['mark'],
#  'taken': ['forsaken', 'shaken'],
#  'cheeks': ['weeks', 'reeks'],
#  'weeks': ['cheeks'],
#  'proved': ['loved'],
#  'loved': ['proved'],
#  'repay': ['day'],
#  'winds': ['minds'],
#  'down': ['frown'],
#  'accumulate': ['hate'],
#  'frown': ['down'],
#  'keen': ['unseen'],
#  'urge': ['purge'],
#  'unseen': ['keen'],
#  'purge': ['urge'],
#  'sweetness': ['meetness'],
#  'feeding': ['needing'],
#  'meetness': ['sweetness'],
#  'needing': ['feeding'],
#  'anticipate': ['state'],
#  'cured': ['assured'],
#  'tears': ['fears', 'clears'],
#  'within': ['win'],
#  'fears': ['tears'],
#  'win': ['within'],
#  'committed': ['fitted'],
#  'never': ['fever'],
#  'fitted': ['committed'],
#  'fever': ['never'],
#  'better': ['greater'],
#  'greater': ['better'],
#  'feel': ['steel'],
#  'steel': ['feel'],
#  'hits': ['fits'],
#  'tendered': ['remembered'],
#  'fits': ['hits'],
#  'fee': ['me'],
#  'being': ['seeing'],
#  'spies': ['eyes'],
#  'level': ['bevel'],
#  'bevel': ['level'],
#  'maintain': ['reign'],
#  'subsist': ['missed'],
#  'missed': ['subsist'],
#  'hold': ['untold', 'bold'],
#  'score': ['more'],
#  'bold': ['hold', 'behold'],
#  'admire': ['desire'],
#  'defy': ['lie'],
#  'haste': ['past'],
#  'unfathered': ['gathered'],
#  'gathered': ['unfathered'],
#  'accident': ['discontent'],
#  'falls': ['calls'],
#  'discontent': ['bent', 'accident'],
#  'calls': ['falls'],
#  'heretic': ['politic'],
#  'politic': ['heretic'],
#  'showers': ['hours'],
#  'canopy': ['eternity'],
#  'honouring': ['ruining'],
#  'ruining': ['honouring'],
#  'favour': ['savour'],
#  'rent': ['spent'],
#  'savour': ['favour'],
#  'bower': ['power'],
#  'black': ['lack'],
#  'lack': ['black'],
#  "play'st": ["sway'st"],
#  "sway'st": ["play'st"],
#  'leap': ['reap'],
#  'reap': ['leap'],
#  'chips': ['lips'],
#  'gait': ['state'],
#  'lips': ['chips'],
#  'kiss': ['this'],
#  'lust': ['trust'],
#  'blame': ['shame'],
#  'straight': ['bait'],
#  'bait': ['straight'],
#  'mad': ['bad', 'had'],
#  'extreme': ['dream'],
#  'dream': ['extreme'],
#  'red': ['head'],
#  'dun': ['sun'],
#  'reeks': ['cheeks'],
#  'sound': ['ground'],
#  'jewel': ['cruel'],
#  'swear': ['bear'],
#  'proceeds': ['deeds'],
#  'disdain': ['pain'],
#  'pain': ['disdain', 'slain', 'gain'],
#  'east': ['west'],
#  'engrossed': ['crossed'],
#  'forsaken': ['taken'],
#  'crossed': ['engrossed'],
#  'ward': ['guard'],
#  'bail': ['gaol'],
#  'guard': ['ward'],
#  'gaol': ['bail'],
#  'bind': ['kind'],
#  'over-plus': ['thus'],
#  'thus': ['over-plus'],
#  'spacious': ['gracious'],
#  'gracious': ['spacious'],
#  "'Will": ['fulfil', 'kill'],
#  'fulfil': ["'Will"],
#  'untold': ['hold'],
#  'Will': ['still'],
#  'looks': ['hooks'],
#  'hooks': ['looks'],
#  'tied': ['ride'],
#  'plot': ['not'],
#  'erred': ['transferred'],
#  'transferred': ['erred'],
#  'subtleties': ['lies'],
#  'suppressed': ['best'],
#  'unjust': ['trust'],
#  'bide': ['aside'],
#  'knows': ['foes'],
#  'enemies': ['injuries'],
#  'injuries': ['enemies'],
#  'press': ['express'],
#  'express': ['press'],
#  'belied': ['wide'],
#  'note': ['dote'],
#  'despise': ['eyes'],
#  'dote': ['note', 'denote'],
#  'delighted': ['invited'],
#  'prone': ['alone'],
#  'invited': ['delighted'],
#  'can': ['man'],
#  'man': ['can'],
#  'reproving': ['loving'],
#  'ornaments': ['rents'],
#  'rents': ['ornaments'],
#  'denied': ['hide'],
#  'dispatch': ['catch'],
#  'chase': ['face'],
#  'bent': ['discontent'],
#  'despair': ['fair'],
#  'evil': ['devil'],
#  'devil': ['evil'],
#  'fiend': ['end', 'friend'],
#  'doubt': ['out'],
#  'greet': ['sweet'],
#  'threw': ['you'],
#  'earth': ['dearth'],
#  'array': ['gay'],
#  'dearth': ['earth'],
#  'excess': ['lease'],
#  'dross': ['loss'],
#  'then': ['men'],
#  'disease': ['please'],
#  'please': ['disease'],
#  'kept': ['except'],
#  'except': ['kept'],
#  'unrest': ['expressed'],
#  'aright': ['sight'],
#  'denote': ['dote'],
#  'no': ['so'],
#  'clears': ['tears'],
#  'partake': ['sake'],
#  'upon': ['moan'],
#  'sway': ['day'],
#  'exceeds': ['deeds'],
#  'abhor': ['more'],
#  'treason': ['reason'],
#  ...}

# %% [markdown]
# # Naive HMM Model

# %%
f = open('data/shakespeare.txt', 'r')

# %%
lines = []
for line in f:
    lines.append(line)
lines = [line.split() for line in lines if len(line.split()) > 1]

# %%
words = []
for line in lines:
    words += line

# %%
text = ''
for line in lines:
    for word in line:
        text += word + ' '

# %%
obs, obs_map = parse_observations(text)

# %%
f2 = open('data/Syllable_dictionary.txt')


words = [line.split() for line in f2]
for i in range(len(words)):
    
    words[i][0] = re.sub(r'[^\w]', '', words[i][0]).lower()
syls = {}
for word in words:
    if is_number(word[1]):
        syls[obs_map[word[0]]] = int(word[1])
    else:
        syls[obs_map[word[0]]] = int(word[2])

# %%
obs, obs_map = parse_observations(text)

# %%
hmm = unsupervised_HMM(obs, 8, 500, get_syls = True)
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100
# Iteration: 110
# Iteration: 120
# Iteration: 130
# Iteration: 140
# Iteration: 150
# Iteration: 160
# Iteration: 170
# Iteration: 180
# Iteration: 190
# Iteration: 200
# Iteration: 210
# Iteration: 220
# Iteration: 230
# Iteration: 240
# Iteration: 250
# Iteration: 260
# Iteration: 270
# Iteration: 280
# Iteration: 290
# Iteration: 300
# Iteration: 310
# Iteration: 320
# Iteration: 330
# Iteration: 340
# Iteration: 350
# Iteration: 360
# Iteration: 370
# Iteration: 380
# Iteration: 390
# Iteration: 400
# Iteration: 410
# Iteration: 420
# Iteration: 430
# Iteration: 440
# Iteration: 450
# Iteration: 460
# Iteration: 470
# Iteration: 480
# Iteration: 490
# Iteration: 500

# %%
hmm.syls = syls

# %%
sample_sonnet_line(hmm, obs_map, 10)
# Out:
# 'Beauty bonds not suffers loveliness and...'

# %%
def get_naive_sonnet():
    sonnet1 = ''
    for i in range(14):
        if i % 4 ==0:
            sonnet1 += '\n'
        sonnet1 += sample_sonnet_line(hmm, obs_map, 10) + ',\n'
    return sonnet1

# %%
for i in range(5):
    print ('SONNET # ', (i+1))
    print (get_naive_sonnet() + '\n\n\n\n')
# Out:
# SONNET #  1
#
# Desire clay some make thou see birth own grew...,
# And is eyes for when such thou buds the love...,
# Heir forgetst will thou she to this might i...,
# To bids my sun give that i you and heaven...,
#
# Thy are way doth all beloved mine a thy...,
# Them old to silvered of wont was thy doth...,
# As whilst in not self must ranged is deceive...,
# Hymn pain by hers her enjoyed that the truth...,
#
# But and one hath place in so with suffered...,
# If give see straight ensconce moving by night...,
# Embassy after my sun part doth thine...,
# His that face is may i store in the grace...,
#
# Me happy respect what is more use hied...,
# All harder old of made hold none pity...,
#
#
#
#
#
# SONNET #  2
#
# On thou i a whose play may seemed my world...,
# Hours kind her where write my our stormbeaten...,
# But no bare for by placed and single...,
# That not surmise will poesy thou as...,
#
# State shame wrackful subject and in the world...,
# Then when tongue weak they slanders stores much feelst...,
# Them thee wrinkles own though death well will me...,
# Mind the vows when now constancy of keeps...,
#
# This up thoughts once intend my star where needs...,
# Wait for fickle thy brow do like brag show...,
# And from can kill bold the lines and the the...,
# Hanging love outbraves it thee said silent...,
#
# Shop proposed with seen full make take thou the...,
# These thy eased thy the woe the my how in...,
#
#
#
#
#
# SONNET #  3
#
# We thou besmeared owe control from thy dregs...,
# To will the heart and thou what to thee a...,
# Flies this no feeding of though no though do...,
# And and from all night the selfsame yore art...,
#
# Lest filching praise take stop not sense feature...,
# For shall remembrance fair adjunct have them...,
# Yet end my hath reason so in you mend...,
# May and that so for badges true mourn in...,
#
# To believe memory i that thou thee...,
# Imprisoned their do worms babe of new and...,
# To as something vilest losing for with...,
# Tis and bark full be is live a your best...,
#
# Make guides so famished am doth straight a thy...,
# Loss faith leave hope toward whilst blame the made which...,
#
#
#
#
#
# SONNET #  4
#
# Full not most friend impanelled is why...,
# And in pleasure is a womans rose in...,
# Thou thou the love i would perjured were so...,
# And mightst would is colour but as the no...,
#
# A sweet grounded die distempered clock thy...,
# Do hell vengeful her dost assistance thou...,
# Bower it renewed to weakness frequent it...,
# Of but bodys therefore these taught thy for...,
#
# To thy when hath with against or with you...,
# Poor my mortgaged added compeers a wealth...,
# Sing second and black buds wouldst better hours...,
# That for with lose lines which ills that you whilst...,
#
# Till should o lends nature were than hell wires...,
# Dear disgrace see sum these lips it say i...,
#
#
#
#
#
# SONNET #  5
#
# An by foolish covetous that be in...,
# The wise self but thy that thou my nor when...,
# That and thee yet rough thy might how stewards...,
# Deeds judgment who hot i merit up my...,
#
# Veins invention hung other set borne my...,
# With young told this will thou the fair when my...,
# My thy disdains of eye in thy loving...,
# The my concord forebemoaned part and...,
#
# Babe swift enjoy be murdrous right eyed yet...,
# Day fame as onward be did evil thou...,
# Life cheek of every different suffring no...,
# Parts worth to gavst thee as came false tonguetied...,
#
# Presagers rose and turned know of not th climbed...,
# Woe white in note if fear loved to thus blest...,

# %%
def rhyming_sonnet_line(hmm, obs_map, r_dic, word_to_rhyme, syl):
    obs_map_r = obs_map_reverser(obs_map)
    syl_count = 0
    
    emission = []
    states = []
    candidates = r_dic[word_to_rhyme]
    word_i = np.random.choice(candidates)
    word_i = re.sub(r'[^\w]', '', word_i).lower()


    
    emission_i = obs_map[word_i]
    
    state = np.random.choice(range(hmm.L))
    
    emission.append(emission_i)
    states.append(state)
    
    syl_count += int(hmm.syls[emission_i])
    
    while syl_count < syl:
        add = np.random.choice(range(hmm.D), p = hmm.O[state])
        add_syls = int(hmm.syls[add])
        if syl_count + add_syls <= syl:
            emission.append(add)
            syl_count += add_syls
            states.append(state)
            pr = list(np.array(hmm.A).transpose()[state])
            pr_sum = sum(pr)
            for i in range(len(pr)):
                pr[i] /= pr_sum
            state = np.random.choice(range(hmm.L), p = pr)
            
    emission.reverse()
    
    sentence = [obs_map_r[i] for i in emission]
    
    return sentence

# %%
def sonnet_line_ending_ryhme(hmm, obs_map, r_dic, syl):
    obs_map_r = obs_map_reverser(obs_map)


    
    emission = []
    states = []
    syl_count = 0
    state = np.random.choice(range(hmm.L))
    add = np.random.choice(range(hmm.D), p = hmm.O[state])
    emission.append(add)
    states.append(state)
    syl_count += int(hmm.syls[add])
    while syl_count < syl:
        add = np.random.choice(range(hmm.D), p = hmm.O[state])
        add_syls = int(hmm.syls[add])
        if syl_count + add_syls <= syl:
            emission.append(add)
            syl_count += add_syls
            state = np.random.choice(range(hmm.L), p = hmm.A[state])
            states.append(state)
    emission = emission[:-1]
    candidates = []
    for key in r_dic.keys():
        key1 = re.sub(r'[^\w]', '', key).lower()
        if int(hmm.syls[obs_map[key1]]) == add_syls:
            candidates.append(key1)
            
    end = np.random.choice(candidates)
    emission.append(obs_map[end])
    
    sentence = [obs_map_r[i] for i in emission]
    return sentence

# %%
rhyming_sonnet_line(hmm, obs_map, r_dic, 'gate', 10)
# Out:
# ['worse', 'unjust', 'she', 'well', 'o', 'can', 'in', 'his', 'state']

# %%
sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10)
# Out:
# ['my', 'heats', 'lively', 'nor', 'seat', 'when', 'thou', 'are', 'crave']

# %%
rhyming_sonnet_line(hmm, obs_map, r_dic, 'wrongs', 10)
# Out:
# ['the', 'under', 'smell', 'are', 'ye', 'of', 'you', 'belongs']

# %%
def generate_rhyming_sonnet():
    sonnet = []
    
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[0][-1], 10))
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[1][-1], 10))
    
    
    
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[4][-1], 10))
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[5][-1], 10))
    
    
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[8][-1], 10))
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[9][-1], 10))
    
    
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[-1][-1], 10))
    
    result = ''
    for line in sonnet:
        for word in line:
            result += word + ' '
        result += '\n'
            
    return result

# %%
print(generate_rhyming_sonnet())
# Out:
# decrees which hell in unfathered bound fight
# thee the long of mayst uprear my face tear
# my thief and to my body the name light
# my day they grow thou with substance appear
# when than no out slavery part of art waste
# my my needs i therefore of shall life stone
# my friend must eyes although on love doth past
# as will travel their things she shall thing none
# like effectually fiend see such from brought
# thou all your winter let will if on can
# heart i a fairest away nor life thought
# self the thing all control kindhearted man
# is thee what me so do lovegod not chief
# my star to speak graces past living grief

# %%
#Checking most used words in the text file
text = open(os.path.join(os.getcwd(), 'data/shakespeare.txt')).read()
wordcloud = text_to_wordcloud(text, title='Shakespeare')

# %%
#Visualizing rough sparsity representation
visualize_sparsities(hmm, O_max_cols=50)

# %%
#FInding words that commonly associate with states
wordclouds = states_to_wordclouds(hmm, obs_map)

# %%
A_mat =np.array(hmm.A)
A_mat>0.25
# Out:
# array([[False, False, False, False, False, False, False,  True],
#        [ True, False, False, False, False,  True, False, False],
#        [False, False, False, False,  True, False, False, False],
#        [False, False, False, False, False, False,  True, False],
#        [False,  True, False,  True, False, False, False, False],
#        [False,  True, False, False, False,  True, False, False],
#        [ True, False, False,  True, False, False, False, False],
#        [False, False,  True, False, False, False,  True, False]])
