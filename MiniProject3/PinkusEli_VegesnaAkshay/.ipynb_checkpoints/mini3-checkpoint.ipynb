# %%
import numpy as np
import re
from HMM import unsupervised_HMM
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    sample_sentence,
    visualize_sparsities,
    animate_emission,
    sample_sonnet_line,
    obs_map_reverser
)

# %%
def is_number(s):
    try:
        int(s)
        return True
    except ValueError:
        return False

# %% [markdown]
# # Working On Ryhming dictinoary

# %%
f2 = open('data/shakespeare.txt', 'r')

# %%
f2 = open('data/shakespeare.txt', 'r')
sonnets = []
sonnet = []
while True:
    line = f2.readline()
    if line == '':
        break
        
    if is_number(line):
        sonnets.append(sonnet)
        sonnet = []
    else:
        sonnet.append(line)
sonnets.append(sonnet)    
sonnets = sonnets[1:]

# for sonnet in sonnets:
#     for i in range(len(sonnet)):
#         if i != len(sonnet) - 1:
#             sonnet[i] = sonnet[i][:-2]
#         else:
#             sonnet[i] = sonnet[i][:-1]

sonnets = [[line for line in sonnet if line != []] for sonnet in sonnets]
sonnets = [[line.split() for line in sonnet] for sonnet in sonnets]
sonnets = [[line for line in sonnet if line != []] for sonnet in sonnets]
sonnets = [[line for line in sonnet] for sonnet in sonnets if len(sonnet) == 14]

for s in range(len(sonnets)):
    for l in range(len(sonnets[s])):
        if sonnets[s][l][-1][-1] in [',', '.', '?', '!', ':', '\'' ,')', ';']:
            sonnets[s][l][-1] = sonnets[s][l][-1][:-1]
            
for s in range(len(sonnets)):
    for l in range(len(sonnets[s])):
        if sonnets[s][l][-1][-1] in [',', '.', '?', '!', ':','\'', ')', ';']:
            sonnets[s][l][-1] = sonnets[s][l][-1][:-1]

# %%
r_dic = dict()
for sonnet in sonnets:
    for i in range(len(sonnet)):
        end = sonnet[i][-1]
        if not (end in r_dic.keys()):
                r_dic[end] = []
        
        
        
        
        
    r_dic[sonnet[0][-1]].append(sonnet[2][-1])
    r_dic[sonnet[2][-1]].append(sonnet[0][-1])

    r_dic[sonnet[1][-1]].append(sonnet[3][-1])
    r_dic[sonnet[3][-1]].append(sonnet[1][-1])
    
    
    
    r_dic[sonnet[4][-1]].append(sonnet[6][-1])
    r_dic[sonnet[6][-1]].append(sonnet[4][-1])
    
    r_dic[sonnet[5][-1]].append(sonnet[7][-1])
    r_dic[sonnet[7][-1]].append(sonnet[5][-1])
    
    
    r_dic[sonnet[8][-1]].append(sonnet[10][-1])
    r_dic[sonnet[10][-1]].append(sonnet[8][-1])
    
    r_dic[sonnet[9][-1]].append(sonnet[11][-1])
    r_dic[sonnet[11][-1]].append(sonnet[9][-1])
    
    r_dic[sonnet[12][-1]].append(sonnet[13][-1])
    r_dic[sonnet[13][-1]].append(sonnet[12][-1])

for key in r_dic.keys():
    r_dic[key] = list(set(r_dic[key]))
r_dic
# Out:
# {'increase': ['decease', 'cease', 'decrease'],
#  'die': ['eye', 'memory', 'dignity', 'lie', 'thereby'],
#  'decease': ['lease', 'increase'],
#  'memory': ['eternity', 'masonry', 'die', 'sky', 'fortify'],
#  'eyes': ['devise',
#   'despise',
#   'spies',
#   'cries',
#   'lies',
#   'arise',
#   'prophecies'],
#  'fuel': ['cruel'],
#  'lies': ['eyes', 'subtleties'],
#  'cruel': ['fuel', 'jewel'],
#  'ornament': ['content'],
#  'spring': ['thing', 'niggarding', 'king', 'sing'],
#  'content': ['ornament', 'spent'],
#  'niggarding': ['spring'],
#  'be': ['see', 'idolatry', 'decree', 'I', 'thee', 'me'],
#  'thee': ['see',
#   'posterity',
#   'usury',
#   'thee',
#   'me',
#   'free',
#   'be',
#   'melancholy'],
#  'brow': ['now', 'mow', 'allow'],
#  'field': ['held'],
#  'now': ['bough', 'brow', 'bow', 'how'],
#  'held': ['field', 'stelled'],
#  'days': ['decays', 'praise', 'lays'],
#  'praise': ['days'],
#  'use': ['excuse', 'abuse', 'muse'],
#  'mine': ['define', 'shine', 'thine', 'line'],
#  'excuse': ['use'],
#  'thine': ['divine', 'shine', 'mine'],
#  'old': ['behold', 'told', 'cold'],
#  'cold': ['behold', 'old', 'uphold'],
#  'viewest': ['renewest'],
#  'another': ['mother'],
#  'renewest': ['viewest'],
#  'mother': ['another'],
#  'womb': ['tomb'],
#  'husbandry': ['posterity'],
#  'tomb': ['come', 'dumb', 'womb'],
#  'posterity': ['enmity', 'thee', 'husbandry'],
#  'prime': ['time'],
#  'see': ['constancy', 'thee', 'be'],
#  'time': ['prime', 'rhyme', 'crime'],
#  'spend': ['lend', 'tend', 'end', 'friend'],
#  'legacy': ['free'],
#  'lend': ['friend', 'tend', 'spend'],
#  'free': ['legacy', 'thee', 'me'],
#  'abuse': ['use'],
#  'give': ['live'],
#  'live': ['achieve', 'give'],
#  'alone': ['gone', 'anon', 'groan', 'one', 'prone'],
#  'deceive': ['leave'],
#  'gone': ['alone', 'on', 'moan'],
#  'leave': ['deceive'],
#  'frame': ['same'],
#  'dwell': ['tell', 'bell', 'excel'],
#  'same': ['name', 'frame'],
#  'excel': ['dwell'],
#  'on': ['groan', 'gone'],
#  'there': ['everywhere', 'where', 'dear', 'forbear', 'near'],
#  'where': ['there', 'clear', 'appear'],
#  'left': ['bereft'],
#  'glass': ['was'],
#  'bereft': ['left'],
#  'was': ['glass', 'pass'],
#  'meet': ['sweet'],
#  'sweet': ['meet', 'greet'],
#  'deface': ['place'],
#  'distilled': ['self-killed'],
#  'place': ['deface', 'case', 'face', 'grace'],
#  'self-killed': ['distilled'],
#  'usury': ['thee'],
#  'loan': ['one'],
#  'one': ['loan', 'none', 'alone'],
#  'art': ['part', 'convert', 'heart', 'depart'],
#  'depart': ['art', 'heart'],
#  'fair': ['air', 'heir', 'despair', 'repair'],
#  'heir': ['fair'],
#  'light': ['bright', 'sight', 'might', 'fight'],
#  'eye': ['alchemy', 'remedy', 'history', 'gravity', 'majesty', 'lie', 'die'],
#  'sight': ['might', 'light', 'aright', 'delight', 'right', 'night'],
#  'majesty': ['eye', 'fly'],
#  'hill': ['still'],
#  'age': ['pilgrimage', 'rage', 'presage', 'equipage', 'page'],
#  'still': ['hill', 'quill', 'ill', 'Will', 'skill', 'will'],
#  'pilgrimage': ['age'],
#  'car': ['are'],
#  'day': ['repay', 'stay', 'away', 'sway', 'way', 'May', 're-survey', 'decay'],
#  'are': ['compare', 'car', 'prepare', 'rare', 'care'],
#  'way': ['stay', 'say', 'day', 'decay'],
#  'noon': ['son'],
#  'son': ['won', 'noon'],
#  'sadly': ['gladly'],
#  'joy': ['annoy'],
#  'gladly': ['sadly'],
#  'annoy': ['joy'],
#  'sounds': ['confounds'],
#  'ear': ['bear'],
#  'confounds': ['sounds'],
#  'bear': ['appear', 'were', 'ear', 'swear', 'wear'],
#  'ordering': ['sing'],
#  'sing': ['ordering', 'prefiguring', 'spring', 'wing', 'bring'],
#  'none': ['stone', 'one'],
#  'life': ['strife', 'knife', 'wife'],
#  'wife': ['life'],
#  'weep': ['keep'],
#  'behind': ['mind', 'kind'],
#  'keep': ['weep', 'asleep'],
#  'mind': ['behind', 'find', 'blind', 'kind'],
#  'it': ['sit', 'it'],
#  'end': ['depend', 'contend', 'friend', 'spend', 'fiend'],
#  'sits': ['commits'],
#  'commits': ['sits', 'befits'],
#  'any': ['many'],
#  'unprovident': ['evident'],
#  'many': ['any'],
#  'evident': ['unprovident'],
#  'hate': ['advocate', 'state', 'debate', 'ruinate', 'accumulate'],
#  'conspire': ['desire'],
#  'ruinate': ['hate'],
#  'desire': ['admire', 'fire', 'conspire', 'require'],
#  'love': ['move', 'remove', 'prove', 'above', 'approve'],
#  'kind': ['mind', 'confined', 'behind', 'bind'],
#  'prove': ['Love', 'love'],
#  'me': ['ye', 'fee', 'thee', 'free', 'be'],
#  "grow'st": ["bestow'st", "ow'st"],
#  'departest': ['convertest'],
#  "bestow'st": ["grow'st"],
#  'convertest': ['departest'],
#  'decay': ['away', 'stay', 'survey', 'day', 'way', 'say', 'clay'],
#  'cease': ['increase'],
#  'away': ['stay', 'day', 'betray', 'play', 'gay', 'decay'],
#  'store': ['more', 'yore', 'shore'],
#  'perish': ['cherish'],
#  'more': ['store', 'score', 'before', 'abhor'],
#  'cherish': ['perish'],
#  'thereby': ['die'],
#  'night': ['plight', 'write', 'bright', 'white', 'delight', 'sight'],
#  'white': ['night', 'delight'],
#  'leaves': ['sheaves'],
#  'herd': ['beard'],
#  'sheaves': ['leaves'],
#  'beard': ['herd'],
#  'make': ['forsake', 'take', 'sake'],
#  'go': ['grow', 'know', 'wilful-slow'],
#  'forsake': ['make'],
#  'grow': ['so', 'go', 'show'],
#  'defence': ['hence', 'offence'],
#  'hence': ['defence'],
#  'prepare': ['are'],
#  'lease': ['decease', 'excess'],
#  'were': ['near', 'bear'],
#  'uphold': ['cold'],
#  'know': ['so', 'go', 'show', 'slow', 'woe'],
#  'so': ['know', 'show', 'grow', 'woe', 'no'],
#  'pluck': ['luck'],
#  'astronomy': ['quality'],
#  'luck': ['pluck'],
#  'quality': ['astronomy'],
#  'tell': ['hell', 'smell', 'well', 'dwell'],
#  'wind': ['find'],
#  'well': ['tell', 'sell', 'hell'],
#  'find': ['mind', 'wind', 'blind'],
#  'derive': ['thrive'],
#  'thrive': ['derive'],
#  'convert': ['art'],
#  'prognosticate': ['date'],
#  'date': ['invocate', 'prognosticate', 'expiate', 'temperate'],
#  'grows': ['shows', 'those'],
#  'moment': ['comment'],
#  'shows': ['grows', 'foes'],
#  'comment': ['moment'],
#  'sky': ['memory'],
#  'decrease': ['increase'],
#  'stay': ['away', 'way', 'day', 'decay'],
#  'you': ['true', 'adieu', 'untrue', 'threw', 'grew', 'new'],
#  'new': ['true', 'view', 'you'],
#  'Time': ['crime', 'rhyme'],
#  'rhyme': ['time', 'Time'],
#  'hours': ['showers', 'flowers'],
#  'unset': ['counterfeit'],
#  'flowers': ['hours'],
#  'counterfeit': ['set', 'unset'],
#  'repair': ['fair'],
#  'pen': ['men', 'again', 'Amen'],
#  'men': ['then', 'pen'],
#  'skill': ['still', 'ill'],
#  'come': ['sum', 'doom', 'tomb'],
#  'deserts': ['parts'],
#  'parts': ['deserts', 'hearts'],
#  'graces': ['faces'],
#  'faces': ['graces'],
#  'tongue': ['wronk', 'young', 'wrong', 'song'],
#  'rage': ['stage', 'age'],
#  'song': ['long', 'tongue'],
#  'temperate': ['date'],
#  'May': ['day'],
#  'shines': ['declines'],
#  'dimmed': ['untrimmed'],
#  'declines': ['shines'],
#  'untrimmed': ['dimmed'],
#  'fade': ['shade', 'made'],
#  "ow'st": ["grow'st"],
#  'shade': ['made', 'fade'],
#  'paws': ['jaws'],
#  'brood': ['blood'],
#  'jaws': ['paws'],
#  'blood': ['good', 'brood'],
#  "fleet'st": ['sweets'],
#  'sweets': ["fleet'st"],
#  'crime': ['time', 'Time'],
#  'allow': ['brow'],
#  'wrong': ['belong', 'tongue', 'young'],
#  'young': ['tongue', 'wrong'],
#  'painted': ['acquainted'],
#  'passion': ['fashion'],
#  'acquainted': ['painted', 'attainted'],
#  'fashion': ['passion'],
#  'rolling': ['controlling'],
#  'gazeth': ['amazeth'],
#  'controlling': ['rolling'],
#  'amazeth': ['gazeth'],
#  'created': ['defeated'],
#  'a-doting': ['nothing'],
#  'defeated': ['created'],
#  'nothing': ['a-doting'],
#  'pleasure': ['treasure', 'measure', 'leisure'],
#  'treasure': ['pleasure'],
#  'muse': ['use'],
#  'verse': ['disperse', 'inhearse', 'rehearse'],
#  'rehearse': ['verse'],
#  'compare': ['are', 'rare'],
#  'gems': ['hems'],
#  'rare': ['compare', 'are', 'care'],
#  'hems': ['gems'],
#  'write': ['bright', 'quite', 'night', 'might'],
#  'bright': ['night', 'might', 'write', 'light'],
#  'air': ['fair'],
#  'sell': ['well'],
#  'behold': ['old', 'cold', 'bold'],
#  'expiate': ['date'],
#  'heart': ['part', 'art', 'depart'],
#  'wary': ['chary'],
#  'will': ['still', 'ill'],
#  'chary': ['wary'],
#  'ill': ['still', 'fill', 'will', 'skill'],
#  'slain': ['pain', 'again'],
#  'again': ['slain', 'stain', 'pen'],
#  'stage': ['rage'],
#  'part': ['desert', 'art', 'heart'],
#  'say': ['lay', 'they', 'way', 'pay', 'decay'],
#  'rite': ['might'],
#  'might': ['rite', 'write', 'light', 'bright', 'appetite', 'spite', 'sight'],
#  'eloquence': ['recompense'],
#  'breast': ['expressed', 'chest', 'best', 'guest'],
#  'recompense': ['eloquence'],
#  'expressed': ['breast', 'unrest', 'best'],
#  'writ': ['wit'],
#  'wit': ['writ', 'sit', 'knit'],
#  'stelled': ['held'],
#  'done': ['sun'],
#  'sun': ['dun', 'done'],
#  'stars': ['bars'],
#  'boast': ['most', 'ghost', 'costs'],
#  'bars': ['stars'],
#  'most': ['boast', 'lost'],
#  'spread': ['buried'],
#  'buried': ['dead', 'spread'],
#  'fight': ['quite', 'light'],
#  'foiled': ['toiled'],
#  'quite': ['recite', 'write', 'fight'],
#  'toiled': ['foiled'],
#  'beloved': ['removed'],
#  'removed': ['beloved'],
#  'vassalage': ['embassage'],
#  'knit': ['wit'],
#  'embassage': ['vassalage'],
#  'moving': ['loving'],
#  'aspect': ['respect'],
#  'loving': ['moving', 'reproving'],
#  'respect': ['effect', 'aspect', 'defect'],
#  'bed': ['head'],
#  'tired': ['expired'],
#  'head': ['dead', 'red', 'bed', 'fled'],
#  'expired': ['tired'],
#  'abide': ['slide', 'wide'],
#  'wide': ['belied', 'abide'],
#  'view': ['true', 'new', 'due'],
#  'plight': ['night'],
#  'rest': ['oppressed', 'best', 'west'],
#  'oppressed': ['rest'],
#  'reign': ['complain', 'maintain'],
#  'complain': ['reign'],
#  'heaven': ['even'],
#  'even': ['heaven'],
#  'longer': ['stronger'],
#  'stronger': ['longer'],
#  'state': ['translate', 'hate', 'anticipate', 'gait', 'gate', 'fate'],
#  'cries': ['eyes'],
#  'fate': ['state'],
#  'hope': ['scope'],
#  'possessed': ['least'],
#  'scope': ['hope'],
#  'least': ['possessed'],
#  'despising': ['arising'],
#  'arising': ['despising'],
#  'gate': ['state'],
#  'brings': ['kings'],
#  'kings': ['things', 'brings'],
#  'thought': ['wrought', 'brought', 'nought', 'sought'],
#  'past': ['waste', 'haste'],
#  'sought': ['thought'],
#  'waste': ['past', 'taste'],
#  'flow': ['woe'],
#  'woe': ['overthrow', 'know', 'so', 'slow', 'flow'],
#  'foregone': ['moan'],
#  "o'er": ['before'],
#  'moan': ['foregone', 'upon', 'gone'],
#  'before': ['more', "o'er", 'shore'],
#  'friend': ['lend', 'end', 'spend', 'fiend'],
#  'hearts': ['parts'],
#  'dead': ["o'er-read",
#   'fled',
#   'bred',
#   'head',
#   'unbred',
#   'buried',
#   'astonished',
#   'remembered'],
#  'tear': ['appear'],
#  'appear': ['year', 'where', 'tear', 'bear'],
#  'lie': ['eye', 'I', 'by', 'deny', 'qualify', 'defy', 'why', 'die'],
#  'cover': ['lover'],
#  're-survey': ['day'],
#  'lover': ['cover'],
#  'brought': ['thought'],
#  'equipage': ['age'],
#  'seen': ['green', 'been', 'queen'],
#  'green': ['seen'],
#  'alchemy': ['eye', 'flattery'],
#  'ride': ['tied', 'hide', 'pride'],
#  'face': ['disgrace', 'chase', 'place', 'grace'],
#  'hide': ['ride', 'pride', 'denied', 'side'],
#  'disgrace': ['face'],
#  'shine': ['mine', 'thine'],
#  'disdaineth': ['staineth'],
#  'staineth': ['disdaineth'],
#  'cloak': ['smoke'],
#  'smoke': ['cloak'],
#  'break': ['speak'],
#  'speak': ['break'],
#  'grief': ['thief', 'chief', 'relief'],
#  'loss': ['cross', 'dross'],
#  'relief': ['grief'],
#  'cross': ['loss', 'after-loss'],
#  'sheds': ['deeds'],
#  'deeds': ['breeds', 'sheds', 'proceeds', 'weeds', 'exceeds'],
#  'mud': ['bud'],
#  'bud': ['mud'],
#  'this': ['amiss', 'is', 'kiss'],
#  'amiss': ['this', 'is'],
#  'sense': ['dispense', 'commence'],
#  'advocate': ['hate'],
#  'commence': ['sense'],
#  'twain': ['remain', 'gain'],
#  'remain': ['twain', 'brain'],
#  'spite': ['delight', 'might'],
#  'effect': ['respect'],
#  'delight': ['night', 'white', 'spite', 'sight'],
#  'shame': ['blame', 'name'],
#  'name': ['shame', 'fame', 'same'],
#  'sort': ['report'],
#  'report': ['sort', 'sport', 'short'],
#  'youth': ['truth'],
#  'truth': ['youth'],
#  'sit': ['wit', 'it'],
#  'despised': ['sufficed'],
#  'sufficed': ['despised'],
#  'invent': ['excellent', 'argument'],
#  'excellent': ['invent'],
#  'worth': ['forth'],
#  'invocate': ['date'],
#  'forth': ['worth'],
#  'bring': ['sing'],
#  'all': ['call'],
#  'call': ['all', 'fall'],
#  'receivest': ['deceivest'],
#  'usest': ['refusest'],
#  'deceivest': ['receivest'],
#  'refusest': ['usest'],
#  'thief': ['grief'],
#  'poverty': ['injury'],
#  'injury': ['poverty', 'liberty'],
#  'foes': ['shows', 'knows'],
#  'befits': ['commits'],
#  'won': ['son'],
#  'assailed': ['prevailed'],
#  'prevailed': ['assailed'],
#  'forbear': ['there'],
#  'dearly': ['nearly'],
#  'chief': ['grief'],
#  'nearly': ['dearly'],
#  'ye': ['me'],
#  'her': ['her'],
#  'gain': ['twain', 'main', 'pain'],
#  'unrespected': ['directed'],
#  'directed': ['unrespected'],
#  'show': ['so', 'know', 'grow', 'owe', 'slow'],
#  'made': ['shade', 'jade', 'fade'],
#  'stand': ['hand', 'land'],
#  'land': ['stand'],
#  'wrought': ['thought'],
#  'slow': ['know', 'woe', 'show'],
#  'fire': ['expire', 'desire'],
#  'slide': ['abide'],
#  'melancholy': ['thee'],
#  'recured': ['assured'],
#  'assured': ['cured', 'endured', 'recured'],
#  'glad': ['sad'],
#  'sad': ['glad'],
#  'war': ['bar'],
#  'bar': ['war'],
#  'right': ['sight'],
#  'deny': ['lie'],
#  'impanelled': ['determined'],
#  'determined': ['impanelled'],
#  'took': ['look'],
#  'other': ['smother'],
#  'look': ['book', 'took'],
#  'smother': ['other'],
#  'feast': ['guest'],
#  'guest': ['breast', 'feast'],
#  'move': ['love'],
#  'thrust': ['trust'],
#  'trust': ['thrust', 'unjust', 'lust'],
#  'care': ['are', 'rare'],
#  'chest': ['breast', 'special-blest'],
#  'fear': ['dear'],
#  'dear': ['fear', 'there'],
#  'defects': ['respects'],
#  'sum': ['come'],
#  'respects': ['defects'],
#  'pass': ['was'],
#  'gravity': ['eye'],
#  'here': ['uprear'],
#  'desert': ['part', 'impart'],
#  'uprear': ['here'],
#  'laws': ['cause'],
#  'cause': ['laws'],
#  'groan': ['alone', 'on'],
#  'side': ['hide', 'pride'],
#  'offence': ['thence', 'defence'],
#  'speed': ['need'],
#  'thence': ['intelligence', 'offence'],
#  'need': ['exceed', 'speed'],
#  'pace': ['race'],
#  'race': ['pace'],
#  'jade': ['made'],
#  'wilful-slow': ['go'],
#  'key': ['survey'],
#  'survey': ['key', 'decay'],
#  'set': ['carcanet', 'debt', 'counterfeit'],
#  'carcanet': ['set'],
#  'special-blest': ['chest'],
#  'pride': ['ride', 'beside', 'aside', 'side', 'hide', 'eyed'],
#  'tend': ['lend', 'mend', 'spend'],
#  'year': ['everywhere', 'appear'],
#  'seem': ['esteem', 'deem'],
#  'deem': ['seem'],
#  'dye': ['wantonly'],
#  'roses': ['discloses'],
#  'wantonly': ['dye'],
#  'discloses': ['roses'],
#  'monuments': ['contents'],
#  'contents': ['monuments'],
#  'overturn': ['burn'],
#  'masonry': ['memory'],
#  'burn': ['overturn'],
#  'enmity': ['posterity'],
#  'room': ['doom'],
#  'doom': ['come', 'room'],
#  'arise': ['eyes'],
#  'said': ['allayed'],
#  'appetite': ['might'],
#  'allayed': ['said'],
#  'fill': ['ill', 'kill'],
#  'fulness': ['dulness'],
#  'kill': ['fill', "'Will"],
#  'dulness': ['fulness'],
#  'require': ['desire'],
#  'hour': ['sour'],
#  'sour': ['hour'],
#  'adieu': ['you'],
#  'suppose': ['those'],
#  'nought': ['thought'],
#  'those': ['rose', 'suppose', 'grows'],
#  'slave': ['crave'],
#  'crave': ['slave'],
#  'leisure': ['pleasure'],
#  'beck': ['check'],
#  'liberty': ['injury'],
#  'check': ['beck'],
#  'strong': ['belong', 'long'],
#  'belong': ['strong', 'wrong'],
#  'hell': ['tell', 'well'],
#  'is': ['his', 'amis', 'this', 'amiss'],
#  'beguiled': ['child'],
#  'amis': ['is'],
#  'child': ['beguiled'],
#  'book': ["o'erlook", 'look'],
#  'they': ['say'],
#  'shore': ['store', 'before'],
#  'contend': ['end'],
#  'crowned': ['confound'],
#  'confound': ['crowned'],
#  'mow': ['brow'],
#  'hand': ['stand', 'brand'],
#  'open': ['broken'],
#  'broken': ['open'],
#  'pry': ['jealousy'],
#  'jealousy': ['pry'],
#  'great': ['defeat'],
#  'awake': ['sake'],
#  'defeat': ['great'],
#  'sake': ['awake', 'make', 'take', 'partake'],
#  'elsewhere': ['near'],
#  'near': ['cheer', 'there', 'elsewhere', 'were'],
#  'remedy': ['eye', 'by'],
#  'account': ['surmount'],
#  'define': ['mine'],
#  'surmount': ['account'],
#  'indeed': ['read'],
#  'antiquity': ['iniquity'],
#  'read': ['indeed'],
#  'iniquity': ['antiquity'],
#  "o'erworn": ['morn'],
#  'morn': ["o'erworn"],
#  'king': ['spring'],
#  'fortify': ['memory'],
#  'knife': ['life'],
#  'defaced': ['down-rased'],
#  'down-rased': ['defaced'],
#  'main': ['gain'],
#  'State': ['ruminate'],
#  'ruminate': ['State'],
#  'choose': ['lose'],
#  'lose': ['choose'],
#  'sea': ['plea'],
#  'power': ['bower', 'flower'],
#  'plea': ['sea'],
#  'flower': ['power'],
#  'out': ['about', 'doubt', 'stout'],
#  'stout': ['out'],
#  'decays': ['days'],
#  'alack': ['back'],
#  'hid': ['forbid'],
#  'back': ['alack'],
#  'forbid': ['hid'],
#  'cry': ['jollity'],
#  'born': ['outworn', 'forsworn'],
#  'jollity': ['cry'],
#  'forsworn': ['scorn', 'torn', 'born'],
#  'misplaced': ['disgraced'],
#  'strumpeted': ['disabled'],
#  'disgraced': ['misplaced'],
#  'disabled': ['strumpeted'],
#  'authority': ['simplicity'],
#  'simplicity': ['authority'],
#  'impiety': ['society'],
#  'achieve': ['live'],
#  'society': ['impiety'],
#  'cheek': ['seek'],
#  'hue': ['anew', 'true', 'grew'],
#  'seek': ['cheek'],
#  'true': ['anew', 'view', 'you', 'new', 'hue'],
#  'veins': ['gains'],
#  'his': ['is'],
#  'gains': ['veins'],
#  'had': ['mad', 'bad'],
#  'bad': ['mad', 'had'],
#  'outworn': ['born'],
#  'gay': ['array', 'away'],
#  'yore': ['store'],
#  'mend': ['commend', 'tend'],
#  'due': ['view', 'review'],
#  'commend': ['mend'],
#  'own': ['shown'],
#  'shown': ['own'],
#  'weeds': ['deeds'],
#  'defect': ['suspect', 'respect'],
#  'suspect': ['defect'],
#  'approve': ['love'],
#  'charged': ['enlarged'],
#  'enlarged': ['charged'],
#  'owe': ['show'],
#  'bell': ['dwell'],
#  'fled': ['dead', 'head'],
#  'not': ['forgot', 'blot', 'plot'],
#  'forgot': ['not'],
#  'clay': ['decay'],
#  'recite': ['quite'],
#  'I': ['lie', 'be'],
#  'impart': ['desert'],
#  'untrue': ['you'],
#  'hang': ['sang'],
#  'sang': ['hang'],
#  'west': ['rest', 'east'],
#  'expire': ['fire'],
#  'by': ['remedy', 'lie'],
#  'long': ['strong', 'song'],
#  'arrest': ['interest'],
#  'interest': ['arrest'],
#  'review': ['due'],
#  'remembered': ['dead', 'tendered'],
#  'contains': ['remains'],
#  'remains': ['contains'],
#  'ground': ['sound', 'found'],
#  'strife': ['life'],
#  'found': ['ground'],
#  'anon': ['alone'],
#  'change': ['strange'],
#  'aside': ['bide', 'pride'],
#  'strange': ['change'],
#  'weed': ['proceed'],
#  'proceed': ['weed'],
#  'argument': ['invent', 'spent'],
#  'spent': ['monument', 'content', 'rent', 'argument'],
#  'told': ['old'],
#  'wear': ['bear'],
#  'taste': ['last', 'waste'],
#  'eternity': ['memory', 'canopy'],
#  'contain': ['brain'],
#  'brain': ['remain', 'contain'],
#  'disperse': ['verse'],
#  'fly': ['majesty'],
#  'wing': ['sing'],
#  'compile': ['style'],
#  'style': ['compile'],
#  'advance': ['ignorance'],
#  'ignorance': ['advance'],
#  'aid': ['decayed'],
#  'grace': ['place', 'face'],
#  'decayed': ['aid'],
#  'word': ['afford'],
#  'afford': ['word'],
#  'pay': ['say'],
#  'fame': ['name'],
#  'afloat': ['boat'],
#  'boat': ['afloat'],
#  'rotten': ['forgotten'],
#  'take': ['make', 'sake'],
#  'forgotten': ['rotten'],
#  'have': ['grave'],
#  'grave': ['have'],
#  "o'er-read": ['dead'],
#  "o'erlook": ['book'],
#  'anew': ['true', 'hue'],
#  'devised': ['sympathized'],
#  'sympathized': ['devised'],
#  'used': ['abused'],
#  'abused': ['used'],
#  'exceed': ['need'],
#  'debt': ['set'],
#  'short': ['report'],
#  'impute': ['mute'],
#  'dumb': ['tomb'],
#  'mute': ['fruit', 'impute'],
#  'devise': ['eyes'],
#  'grew': ['you', 'hue'],
#  'glory': ['story'],
#  'story': ['glory'],
#  'clear': ['where'],
#  'curse': ['worse'],
#  'worse': ['curse'],
#  'compiled': ['filed'],
#  'quill': ['still'],
#  'filed': ['compiled'],
#  'words': ['affords'],
#  'Amen': ['pen'],
#  'affords': ['words'],
#  'inhearse': ['verse'],
#  'astonished': ['dead'],
#  'ghost': ['boast'],
#  'intelligence': ['thence'],
#  'line': ['mine'],
#  'possessing': ['releasing'],
#  'estimate': ['determinate'],
#  'releasing': ['possessing'],
#  'determinate': ['estimate'],
#  'granting': ['wanting'],
#  'deserving': ['swerving'],
#  'wanting': ['granting'],
#  'swerving': ['deserving'],
#  'knowing': ['growing'],
#  'mistaking': ['making'],
#  'growing': ['knowing'],
#  'making': ['mistaking'],
#  'flatter': ['matter'],
#  'matter': ['flatter'],
#  'scorn': ['forsworn'],
#  'attainted': ['acquainted'],
#  'too': ['do'],
#  'do': ['too'],
#  'fault': ['halt'],
#  'halt': ['fault'],
#  'wronk': ['tongue'],
#  'debate': ['hate'],
#  'bow': ['now'],
#  'after-loss': ['cross'],
#  'sorrow': ['morrow'],
#  'morrow': ['sorrow'],
#  'overthrow': ['woe'],
#  'last': ['taste'],
#  'force': ['horse'],
#  'horse': ['force'],
#  'measure': ['pleasure'],
#  'best': ['suppressed', 'indigest', 'rest', 'breast', 'expressed'],
#  'costs': ['boast'],
#  'wrongs': ['belongs'],
#  'belongs': ['wrongs'],
#  'depend': ['end'],
#  'blot': ['got', 'not'],
#  'history': ['eye'],
#  'decree': ['be'],
#  'stone': ['none'],
#  'expense': ['excellence'],
#  'excellence': ['difference', 'expense'],
#  'dignity': ['die'],
#  'rose': ['enclose', 'those'],
#  'enclose': ['rose'],
#  'sport': ['report', 'resort'],
#  'got': ['blot'],
#  'privilege': ['edge'],
#  'edge': ['privilege'],
#  'wantonness': ['less'],
#  'less': ['wantonness'],
#  'resort': ['sport'],
#  'queen': ['seen'],
#  'esteemed': ['deemed'],
#  'deemed': ['esteemed'],
#  'betray': ['away', 'may'],
#  'translate': ['state'],
#  'been': ['seen'],
#  'everywhere': ['there', 'year'],
#  'fruit': ['mute'],
#  'cheer': ['near'],
#  'trim': ['him'],
#  'thing': ['spring'],
#  'him': ['trim'],
#  'smell': ['tell'],
#  'play': ['away'],
#  'redeem': ['esteem'],
#  'esteem': ['seem', 'redeem'],
#  'amends': ['depends'],
#  'dyed': ['dignified'],
#  'depends': ['amends'],
#  'dignified': ['dyed'],
#  'fixed': ['intermixed'],
#  'lay': ['say'],
#  'intermixed': ['fixed'],
#  'how': ['now'],
#  'seeming': ['esteeming'],
#  'esteeming': ['seeming'],
#  'lays': ['days'],
#  'bough': ['now'],
#  'beside': ['pride'],
#  'eyed': ['pride'],
#  'turned': ['burned'],
#  'burned': ['turned'],
#  'perceived': ['deceived'],
#  'deceived': ['perceived'],
#  'unbred': ['dead'],
#  'idolatry': ['be'],
#  'confined': ['kind', 'grind'],
#  'difference': ['excellence'],
#  'wights': ['knights'],
#  'knights': ['wights'],
#  'prophecies': ['eyes'],
#  'prefiguring': ['sing'],
#  'soul': ['control'],
#  'control': ['soul'],
#  'endured': ['assured'],
#  'presage': ['age'],
#  'subscribes': ['tribes'],
#  'tribes': ['subscribes'],
#  'monument': ['spent'],
#  'character': ['register'],
#  'spirit': ['merit'],
#  'register': ['character'],
#  'merit': ['spirit'],
#  'divine': ['thine'],
#  'case': ['place'],
#  'page': ['age'],
#  'bred': ['dead'],
#  'qualify': ['lie'],
#  'ranged': ['exchanged'],
#  'exchanged': ['ranged'],
#  'stain': ['again'],
#  'reigned': ['stained'],
#  'stained': ['reigned'],
#  'good': ['blood'],
#  'above': ['love'],
#  'grind': ['confined'],
#  'chide': ['provide'],
#  'provide': ['chide'],
#  'breeds': ['deeds'],
#  'brand': ['hand'],
#  'subdued': ['renewed'],
#  'renewed': ['subdued'],
#  'drink': ['think'],
#  'infection': ['correction'],
#  'think': ['drink'],
#  'correction': ['infection'],
#  'strive': ['alive'],
#  'alive': ['strive'],
#  'dispense': ['sense'],
#  'about': ['out'],
#  'blind': ['mind', 'find'],
#  'latch': ['catch'],
#  'catch': ['latch', 'dispatch'],
#  'creature': ['feature'],
#  'feature': ['creature'],
#  'flattery': ['alchemy'],
#  'indigest': ['best'],
#  'resemble': ['assemble'],
#  'assemble': ['resemble'],
#  'seeing': ['being', "'greeing"],
#  'up': ['cup'],
#  "'greeing": ['seeing'],
#  'cup': ['up'],
#  'sin': ['begin'],
#  'begin': ['sin'],
#  'dearer': ['clearer'],
#  'why': ['lie'],
#  'clearer': ['dearer'],
#  'accidents': ['intents'],
#  'intents': ['accidents'],
#  'things': ['kings'],
#  'tyranny': ['incertainty'],
#  'incertainty': ['tyranny'],
#  'minds': ['finds', 'winds'],
#  'finds': ['minds'],
#  'remove': ['love'],
#  'mark': ['bark'],
#  'shaken': ['taken'],
#  'bark': ['mark'],
#  'taken': ['shaken', 'forsaken'],
#  'cheeks': ['reeks', 'weeks'],
#  'weeks': ['cheeks'],
#  'proved': ['loved'],
#  'loved': ['proved'],
#  'repay': ['day'],
#  'winds': ['minds'],
#  'down': ['frown'],
#  'accumulate': ['hate'],
#  'frown': ['down'],
#  'keen': ['unseen'],
#  'urge': ['purge'],
#  'unseen': ['keen'],
#  'purge': ['urge'],
#  'sweetness': ['meetness'],
#  'feeding': ['needing'],
#  'meetness': ['sweetness'],
#  'needing': ['feeding'],
#  'anticipate': ['state'],
#  'cured': ['assured'],
#  'tears': ['fears', 'clears'],
#  'within': ['win'],
#  'fears': ['tears'],
#  'win': ['within'],
#  'committed': ['fitted'],
#  'never': ['fever'],
#  'fitted': ['committed'],
#  'fever': ['never'],
#  'better': ['greater'],
#  'greater': ['better'],
#  'feel': ['steel'],
#  'steel': ['feel'],
#  'hits': ['fits'],
#  'tendered': ['remembered'],
#  'fits': ['hits'],
#  'fee': ['me'],
#  'being': ['seeing'],
#  'spies': ['eyes'],
#  'level': ['bevel'],
#  'bevel': ['level'],
#  'maintain': ['reign'],
#  'subsist': ['missed'],
#  'missed': ['subsist'],
#  'hold': ['bold', 'untold'],
#  'score': ['more'],
#  'bold': ['behold', 'hold'],
#  'admire': ['desire'],
#  'defy': ['lie'],
#  'haste': ['past'],
#  'unfathered': ['gathered'],
#  'gathered': ['unfathered'],
#  'accident': ['discontent'],
#  'falls': ['calls'],
#  'discontent': ['bent', 'accident'],
#  'calls': ['falls'],
#  'heretic': ['politic'],
#  'politic': ['heretic'],
#  'showers': ['hours'],
#  'canopy': ['eternity'],
#  'honouring': ['ruining'],
#  'ruining': ['honouring'],
#  'favour': ['savour'],
#  'rent': ['spent'],
#  'savour': ['favour'],
#  'bower': ['power'],
#  'black': ['lack'],
#  'lack': ['black'],
#  "play'st": ["sway'st"],
#  "sway'st": ["play'st"],
#  'leap': ['reap'],
#  'reap': ['leap'],
#  'chips': ['lips'],
#  'gait': ['state'],
#  'lips': ['chips'],
#  'kiss': ['this'],
#  'lust': ['trust'],
#  'blame': ['shame'],
#  'straight': ['bait'],
#  'bait': ['straight'],
#  'mad': ['had', 'bad'],
#  'extreme': ['dream'],
#  'dream': ['extreme'],
#  'red': ['head'],
#  'dun': ['sun'],
#  'reeks': ['cheeks'],
#  'sound': ['ground'],
#  'jewel': ['cruel'],
#  'swear': ['bear'],
#  'proceeds': ['deeds'],
#  'disdain': ['pain'],
#  'pain': ['slain', 'gain', 'disdain'],
#  'east': ['west'],
#  'engrossed': ['crossed'],
#  'forsaken': ['taken'],
#  'crossed': ['engrossed'],
#  'ward': ['guard'],
#  'bail': ['gaol'],
#  'guard': ['ward'],
#  'gaol': ['bail'],
#  'bind': ['kind'],
#  'over-plus': ['thus'],
#  'thus': ['over-plus'],
#  'spacious': ['gracious'],
#  'gracious': ['spacious'],
#  "'Will": ['fulfil', 'kill'],
#  'fulfil': ["'Will"],
#  'untold': ['hold'],
#  'Will': ['still'],
#  'looks': ['hooks'],
#  'hooks': ['looks'],
#  'tied': ['ride'],
#  'plot': ['not'],
#  'erred': ['transferred'],
#  'transferred': ['erred'],
#  'subtleties': ['lies'],
#  'suppressed': ['best'],
#  'unjust': ['trust'],
#  'bide': ['aside'],
#  'knows': ['foes'],
#  'enemies': ['injuries'],
#  'injuries': ['enemies'],
#  'press': ['express'],
#  'express': ['press'],
#  'belied': ['wide'],
#  'note': ['dote'],
#  'despise': ['eyes'],
#  'dote': ['denote', 'note'],
#  'delighted': ['invited'],
#  'prone': ['alone'],
#  'invited': ['delighted'],
#  'can': ['man'],
#  'man': ['can'],
#  'reproving': ['loving'],
#  'ornaments': ['rents'],
#  'rents': ['ornaments'],
#  'denied': ['hide'],
#  'dispatch': ['catch'],
#  'chase': ['face'],
#  'bent': ['discontent'],
#  'despair': ['fair'],
#  'evil': ['devil'],
#  'devil': ['evil'],
#  'fiend': ['end', 'friend'],
#  'doubt': ['out'],
#  'greet': ['sweet'],
#  'threw': ['you'],
#  'earth': ['dearth'],
#  'array': ['gay'],
#  'dearth': ['earth'],
#  'excess': ['lease'],
#  'dross': ['loss'],
#  'then': ['men'],
#  'disease': ['please'],
#  'please': ['disease'],
#  'kept': ['except'],
#  'except': ['kept'],
#  'unrest': ['expressed'],
#  'aright': ['sight'],
#  'denote': ['dote'],
#  'no': ['so'],
#  'clears': ['tears'],
#  'partake': ['sake'],
#  'upon': ['moan'],
#  'sway': ['day'],
#  'exceeds': ['deeds'],
#  'abhor': ['more'],
#  'treason': ['reason'],
#  ...}

# %% [markdown]
# # Naive HMM Model

# %%
f = open('data/shakespeare.txt', 'r')

# %%
lines = []
for line in f:
    lines.append(line)
lines = [line.split() for line in lines if len(line.split()) > 1]

# %%
words = []
for line in lines:
    words += line

# %%
text = ''
for line in lines:
    for word in line:
        text += word + ' '

# %%
obs, obs_map = parse_observations(text)

# %%
f2 = open('data/Syllable_dictionary.txt')

words = [line.split() for line in f2]
for i in range(len(words)):
    
    words[i][0] = re.sub(r'[^\w]', '', words[i][0]).lower()
syls = {}
for word in words:
    if is_number(word[1]):
        syls[obs_map[word[0]]] = int(word[1])
    else:
        syls[obs_map[word[0]]] = int(word[2])

# %%
obs, obs_map = parse_observations(text)

# %%
hmm = unsupervised_HMM(obs, 15, 100, get_syls = True)
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100

# %%
hmm.syls = syls

# %%
result = ''
for i in range(14):
    result += sample_emission(np.random.choice([6,7,8,9])) + ',\n'
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-3abbb93e46f3> in <module>()
#       1 result = ''
#       2 for i in range(14):
# ----> 3     result += sample_emission(np.random.choice([6,7,8,9])) + ',\n'
#       4 result
#
# NameError: name 'sample_emission' is not defined

# %%
sample_sonnet_line(hmm, obs_map, 10)

# %%
def get_naive_sonnet():
    sonnet1 = ''
    for i in range(14):
        if i % 4 ==0:
            sonnet1 += '\n'
        sonnet1 += sample_sonnet_line(hmm, obs_map, 10) + ',\n'
    return sonnet1

# %%
for i in range(5):
    print ('SONNET # ', (i+1))
    print (get_naive_sonnet() + '\n\n\n\n')
# Out:
# SONNET #  1
#
# Perish which better heart of by thy than...,
# Beauteous east child of tomb loves my be to...,
# Tops all thou be cloud so was well eye that...,
# Flowers steel are invention how doth thee self...,
#
# Out which to the own heart if lord swift heavens...,
# Might must gone veil not mind now made slandered...,
# In is her fair blindness jewel apple...,
# Love doth which but wouldst they you are a out...,
#
# The deaths breath for since it friends will all me...,
# Shalt appears autumn so while idle so...,
# Air barren right with that place and thou am...,
# Bear with as prizing with in flower might but...,
#
# Spirits thy churl got the constancy which...,
# Vanishing make impart in respect with...,
#
#
#
#
#
# SONNET #  2
#
# I care may spite should this wilfulness bail...,
# Pattern worth for thy reserve me pity...,
# Locked angel strangle beard prize how am give...,
# Better besmeared stage cruel my on your...,
#
# See no love old heart penury sweet not...,
# For memory teach niggard steepy to...,
# Besides and in having being or divine...,
# She then but have birth so all will thine love...,
#
# Doth not ripe these fear admired this and...,
# Windows my a then but being than she but...,
# To to him which thee green i have i cut...,
# Mock thy knowst excuse was you in thy i...,
#
# Wilfulness shame and divert in more have...,
# Else livery are come their who o least...,
#
#
#
#
#
# SONNET #  3
#
# Your one look i pity heart often i...,
# Therefore wantonly and engrossed niggard...,
# Wherever have you might from still rotten...,
# Monument tickled lovst your this saith to...,
#
# Urge ill but gentle face but is their hath...,
# Rich nor mountain three to night you love heres...,
# To from i far first doth need spurring in...,
# You born rolling doing his breath of on...,
#
# And remembered his away my to brand...,
# In never thee fate it back adulterate...,
# In in womens that i the ill in eyes...,
# The their pride but since my when heavenly lies...,
#
# A scarcely me your he knew if ride as...,
# In though stay mind my we unthrifty be...,
#
#
#
#
#
# SONNET #  4
#
# Presenteth a shadow and his thing is...,
# Whereon but of do feil jewels candles...,
# Bold own not thee i with see make doth some...,
# Neck note drinks it dote thou not my the sweet...,
#
# Now to such brass do no mine of knife her...,
# When in is sail boast good among taught that...,
# Shall nobler tempting my love their mind see...,
# Some thee for anew when lambs phrase hath to...,
#
# In infection scope root this a many what...,
# Art sweets faith more made and thy rose be blamed...,
# Eyes foiled i with pain mistake making bed...,
# Do which your self so that loves seem were time...,
#
# So much cloud with thousand tallies or were...,
# So as foist boast is thy grace through thou as...,
#
#
#
#
#
# SONNET #  5
#
# Be angel it to check razed desire i...,
# Spendst downrased her have immured than thou...,
# Take that to miser with shows she trial...,
# Merit no impair come essays gilding...,
#
# Loving sight dials as my love too saved...,
# Greatest sings painting to haply you in...,
# My then to find the came if untainted...,
# Eye in my toward recite is weeds your pen...,
#
# To creating fixed to still th are who thou...,
# Dreams out tonguetied memorial pleased is do...,
# A a his one play against ere sword my...,
# Flattery soul under natures judgment of...,
#
# Not fair to flatter my thinks o doth head...,
# Kind from and mortal these for when whereof...,

# %%
def rhyming_sonnet_line(hmm, obs_map, r_dic, word_to_rhyme, syl):
    obs_map_r = obs_map_reverser(obs_map)
    syl_count = 0
    
    emission = []
    states = []
    candidates = r_dic[word_to_rhyme]
    word_i = np.random.choice(candidates)
    word_i = re.sub(r'[^\w]', '', word_i).lower()


    
    emission_i = obs_map[word_i]
    
    state = np.random.choice(range(hmm.L))
    
    emission.append(emission_i)
    states.append(state)
    
    syl_count += int(hmm.syls[emission_i])
    
    while syl_count < syl:
        add = np.random.choice(range(hmm.D), p = hmm.O[state])
        add_syls = int(hmm.syls[add])
        if syl_count + add_syls <= syl:
            emission.append(add)
            syl_count += add_syls
            states.append(state)
            pr = list(np.array(hmm.A).transpose()[state])
            pr_sum = sum(pr)
            for i in range(len(pr)):
                pr[i] /= pr_sum
            state = np.random.choice(range(hmm.L), p = pr)
            
    emission.reverse()
    
    sentence = [obs_map_r[i] for i in emission]
    
    return sentence

# %%
def sonnet_line_ending_ryhme(hmm, obs_map, r_dic, syl):
    obs_map_r = obs_map_reverser(obs_map)


    
    emission = []
    states = []
    syl_count = 0
    state = np.random.choice(range(hmm.L))
    add = np.random.choice(range(hmm.D), p = hmm.O[state])
    emission.append(add)
    states.append(state)
    syl_count += int(hmm.syls[add])
    while syl_count < syl:
        add = np.random.choice(range(hmm.D), p = hmm.O[state])
        add_syls = int(hmm.syls[add])
        if syl_count + add_syls <= syl:
            emission.append(add)
            syl_count += add_syls
            state = np.random.choice(range(hmm.L), p = hmm.A[state])
            states.append(state)
    emission = emission[:-1]
    candidates = []
    for key in r_dic.keys():
        key1 = re.sub(r'[^\w]', '', key).lower()
        if int(hmm.syls[obs_map[key1]]) == add_syls:
            candidates.append(key1)
            
    end = np.random.choice(candidates)
    emission.append(obs_map[end])
    
    sentence = [obs_map_r[i] for i in emission]
    return sentence

# %%
rhyming_sonnet_line(hmm, obs_map, r_dic, 'gate', 10)
# Out:
# ['youth', 'if', 'holy', 'self', 'now', 'no', 'thinks', 'of', 'state']

# %%
sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10)
# Out:
# ['all', 'sufficed', 'he', 'tells', 'wear', 'heavenly', 'how', 'slave']

# %%
rhyming_sonnet_line(hmm, obs_map, r_dic, 'wrongs', 10)
# Out:
# ['raven', 'deceived', 'what', 'judgement', 'belongs']

# %%
def generate_rhyming_sonnet():
    sonnet = []
    
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[0][-1], 10))
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[1][-1], 10))
    
    
    
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[4][-1], 10))
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[5][-1], 10))
    
    
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[8][-1], 10))
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[9][-1], 10))
    
    
    sonnet.append(sonnet_line_ending_ryhme(hmm, obs_map, r_dic, 10))
    sonnet.append(rhyming_sonnet_line(hmm, obs_map, r_dic, sonnet[-1][-1], 10))
    
    result = ''
    for line in sonnet:
        for word in line:
            result += word + ' '
        result += '\n'
            
    return result

# %%
print(generate_rhyming_sonnet())
# Out:
# and a king express when to be confound
# stormy what my seem being a thou ah sun
# lack to thee and is show kill oppressed crowned
# cast his yet not prize times unfolding dun
# th love lest these purpose against beautys grief
# and are seconds for glory of a swear
# given everywhere cry make the hours and thief
# soft preventst but play what above thy bear
# of cure cheek loved well but hides to dead kept
# me authority me beloved defence
# till i in these thunder shames of except
# me like greater mine times gored fight are they hence
# clearer truth day tell entombed from date
# loves robbery but to truth to temperate

# %%
import datetime
print(datetime.datetime.now().time())
# Out:
# 19:16:55.337465

# %%
print(datetime.datetime.now().time())
hmm = unsupervised_HMM(obs, 250, 1, get_syls = True)
print(datetime.datetime.now().time())
# Out:
# 19:16:55.350483
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-41144b874fc0> in <module>()
#       1 print(datetime.datetime.now().time())
# ----> 2 hmm = unsupervised_HMM(obs, 250, 1, get_syls = True)
#       3 print(datetime.datetime.now().time())
#
# /Users/eli/OneDrive - California Institute of Technology/Classes-MBP/Soph Winter/cs 155/MiniProject3/src/HMM.py in unsupervised_HMM(X, n_states, N_iters, get_syls)
#     612     # Train an HMM with unlabeled data.
#     613     HMM = HiddenMarkovModel(A, O, get_syls = get_syls)
# --> 614     HMM.unsupervised_learning(X, N_iters)
#     615
#     616     return HMM
#
# /Users/eli/OneDrive - California Institute of Technology/Classes-MBP/Soph Winter/cs 155/MiniProject3/src/HMM.py in unsupervised_learning(self, X, N_iters)
#     374                                                     * self.A[curr][nxt] \
#     375                                                     * self.O[nxt][x[t]] \
# --> 376                                                     * betas[t + 1][nxt]
#     377
#     378                     # Normalize:
#
# KeyboardInterrupt:

# %%
print(datetime.datetime.now().time())
hmm = unsupervised_HMM(obs, 300, 1, get_syls = True)
print(datetime.datetime.now().time())

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

states = [1,5,10,15,20,25,30,35,40,50,60,70,100,150,200, 250,300]
times = [.5,2,4,8,13,19,26,35,45,67,100,134,260,610,1080, 1650, 2400]

plt.plot(states, times)
plt.xlabel('Hidden States')
plt.ylabel('Approx. Time Per Epoch')
plt.title('Train Timee vs. Num. Hidden States')
plt.savefig('train_time.png', dpi = 400)
