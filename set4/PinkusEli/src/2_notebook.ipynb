# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Flatten, Dropout
from keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
NUM_CLASSES = 10
# Out:
# Using TensorFlow backend.

# %%
# !pip freeze | grep keras

# %%
def normalize (X, val):
    return np.array([[X[i][j] / val for j in range(len(X[0]))] for i in range(len(X))])

# %%
y_train = keras.utils.to_categorical(y_train, num_classes=NUM_CLASSES)
y_test = keras.utils.to_categorical(y_test, num_classes=NUM_CLASSES)
X_train = np.reshape(X_train,(len(X_train),(len(X_train[0][0]))**2))
X_test = np.reshape(X_test,(len(X_test),(len(X_test[0][0]))**2))

X_train = normalize(X_train, 255.)
X_test = normalize(X_test, 255.)

# %%
model = Sequential()
model.add(Dense(80, input_shape=(784,)))
model.add(Activation ('relu'))
model.add(Dropout(.15))
model.add(Dense(20))
model.add(Dense(10))
model.add(Activation('softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])

fit = model.fit(X_train, y_train, batch_size=128, nb_epoch=100,
    verbose=1)

## Printing the accuracy of our model, according to the loss function specified in model.compile above
score = model.evaluate(X_test, y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_112 (Dense)            (None, 80)                62800
# _________________________________________________________________
# activation_108 (Activation)  (None, 80)                0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 80)                0
# _________________________________________________________________
# dense_113 (Dense)            (None, 20)                1620
# _________________________________________________________________
# dense_114 (Dense)            (None, 10)                210
# _________________________________________________________________
# activation_109 (Activation)  (None, 10)                0
# =================================================================
# Total params: 64,630
# Trainable params: 64,630
# Non-trainable params: 0
# _________________________________________________________________
# /Users/eli/anaconda/lib/python3.6/site-packages/keras/models.py:944: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/100
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.4223 - acc: 0.8782
# Epoch 2/100
# 60000/60000 [==============================] - 2s 40us/step - loss: 0.1977 - acc: 0.9415
# Epoch 3/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.1509 - acc: 0.9548
# Epoch 4/100
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.1233 - acc: 0.9628
# Epoch 5/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.1067 - acc: 0.9672
# Epoch 6/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0940 - acc: 0.9702
# Epoch 7/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0855 - acc: 0.9732
# Epoch 8/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0761 - acc: 0.9763
# Epoch 9/100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0721 - acc: 0.9773
# Epoch 10/100
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.0653 - acc: 0.9789
# Epoch 11/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0607 - acc: 0.9805
# Epoch 12/100
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.0578 - acc: 0.9812
# Epoch 13/100
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.0530 - acc: 0.9826
# Epoch 14/100
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.0515 - acc: 0.9834
# Epoch 15/100
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0484 - acc: 0.9837
# Epoch 16/100
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0437 - acc: 0.9853
# Epoch 17/100
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.0430 - acc: 0.9854
# Epoch 18/100
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0412 - acc: 0.9863
# Epoch 19/100
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0399 - acc: 0.9864
# Epoch 20/100
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0395 - acc: 0.9862
# Epoch 21/100
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.0379 - acc: 0.9872
# Epoch 22/100
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0352 - acc: 0.9882
# Epoch 23/100
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0334 - acc: 0.9883
# Epoch 24/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0343 - acc: 0.9886
# Epoch 25/100
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.0337 - acc: 0.9884
# Epoch 26/100
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.0310 - acc: 0.9892
# Epoch 27/100
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0321 - acc: 0.9887
# Epoch 28/100
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.0316 - acc: 0.9890
# Epoch 29/100
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0295 - acc: 0.9894
# Epoch 30/100
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.0281 - acc: 0.9902
# Epoch 31/100
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.0281 - acc: 0.9903
# Epoch 32/100
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.0290 - acc: 0.9901
# Epoch 33/100
# 60000/60000 [==============================] - 3s 51us/step - loss: 0.0264 - acc: 0.9907
# Epoch 34/100
# 60000/60000 [==============================] - 3s 57us/step - loss: 0.0263 - acc: 0.9907
# Epoch 35/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0257 - acc: 0.9911
# Epoch 36/100
# 60000/60000 [==============================] - 3s 52us/step - loss: 0
100
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.0147 - acc: 0.9951
# Test score: 0.12535707663121862
# Test accuracy: 0.9785

# %%
model = Sequential()
model.add(Dense(150, input_shape=(784,)))
model.add(Activation ('relu'))
model.add(Dropout(.15))
model.add(Dense(40))
model.add(Activation ('relu'))
model.add(Dense(10))
model.add(Activation ('relu'))

## Once you one-hot encode the data labels, the line below should be predicting probabilities of each of the 10 classes
## e.g. it should read: model.add(Dense(10)), not model.add(Dense(1))
model.add(Dense(10))
model.add(Activation('softmax'))

## Printing a summary of the layers and weights in your model
model.summary()

## In the line below we have specified the loss function as 'mse' (Mean Squared Error) because in the above code we did not one-hot encode the labels.
## In your implementation, since you are one-hot encoding the labels, you should use 'categorical_crossentropy' as your loss.
## You will likely have the best results with RMS prop or Adam as your optimizer.  In the line below we use Adadelta
model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])

fit = model.fit(X_train, y_train, batch_size=128, nb_epoch=100,
    verbose=1)

## Printing the accuracy of our model, according to the loss function specified in model.compile above
score = model.evaluate(X_test, y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_115 (Dense)            (None, 150)               117750
# _________________________________________________________________
# activation_110 (Activation)  (None, 150)               0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 150)               0
# _________________________________________________________________
# dense_116 (Dense)            (None, 40)                6040
# _________________________________________________________________
# activation_111 (Activation)  (None, 40)                0
# _________________________________________________________________
# dense_117 (Dense)            (None, 10)                410
# _________________________________________________________________
# activation_112 (Activation)  (None, 10)                0
# _________________________________________________________________
# dense_118 (Dense)            (None, 10)                110
# _________________________________________________________________
# activation_113 (Activation)  (None, 10)                0
# =================================================================
# Total params: 124,310
# Trainable params: 124,310
# Non-trainable params: 0
# _________________________________________________________________
# /Users/eli/anaconda/lib/python3.6/site-packages/keras/models.py:944: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/100
#  - ETA: 50s - loss: 2.0512 - acc: 0.3047
# Epoch 2/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.1741 - acc: 0.9485
# Epoch 3/100
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.1262 - acc: 0.9622
# Epoch 4/100
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.1014 - acc: 0.9705
# Epoch 5/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0822 - acc: 0.9750
# Epoch 6/100
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.0698 - acc: 0.9787
# Epoch 7/100
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.0632 - acc: 0.9803
# Epoch 8/100
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0532 - acc: 0.9836
# Epoch 9/100
# 60000/60000 [==============================] - 3s 47us/step - loss: 0.0495 - acc: 0.9837
# Epoch 10/100
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0446 - acc: 0.9855
# Epoch 11/100
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0400 - acc: 0.9867
# Epoch 12/100
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.0361 - acc: 0.9882
# Epoch 13/100
# 60000/60000 [==============================] - 4s 59us/step - loss: 0.0358 - acc: 0.9881
# Epoch 14/100
# 60000/60000 [==============================] - 4s 66us/step - loss: 0.0339 - acc: 0.9889
# Epoch 15/100
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.0308 - acc: 0.9900
# Epoch 16/100
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.0306 - acc: 0.9896
# Epoch 17/100
# 60000/60000 [==============================] - 4s 60us/step - loss: 0.0258 - acc: 0.9910
# Epoch 18/100
# 60000/60000 [==============================] - 4s 61us/step - loss: 0.0258 - acc: 0.9910
# Epoch 19/100
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.0255 - acc: 0.9912
# Epoch 20/100
# 60000/60000 [==============================] - 4s 62us/step - loss: 0.0233 - acc: 0.9919
# Epoch 21/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0233 - acc: 0.9922
# Epoch 22/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0218 - acc: 0.9927
# Epoch 23/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0221 - acc: 0.9930
# Epoch 24/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0224 - acc: 0.9924
# Epoch 25/100
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0185 - acc: 0.9937
# Epoch 26/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0204 - acc: 0.9930
# Epoch 27/100
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0183 - acc: 0.9937
# Epoch 28/100
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0183 - acc: 0.9937
# Epoch 29/100
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0170 - acc: 0.9941
# Epoch 30/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0158 - acc: 0.9945
# Epoch 31/100
# 60000/60000 [==============================] - 4s 66us/step - loss: 0.0163 - acc: 0.9945
# Epoch 32/100
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.
100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0089 - acc: 0.9973
# Epoch 91/100
# 60000/60000 [==============================] - 3s 58us/step - loss: 0.0081 - acc: 0.9975
# Epoch 92/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0091 - acc: 0.9973
# Epoch 93/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0089 - acc: 0.9974
# Epoch 94/100
# 60000/60000 [==============================] - 3s 56us/step - loss: 0.0095 - acc: 0.9972
# Epoch 95/100
# 60000/60000 [==============================] - 3s 57us/step - loss: 0.0071 - acc: 0.9976
# Epoch 96/100
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.0079 - acc: 0.9975
# Epoch 97/100
# 60000/60000 [==============================] - 3s 57us/step - loss: 0.0078 - acc: 0.9976
# Epoch 98/100
# 60000/60000 [==============================] - 3s 55us/step - loss: 0.0086 - acc: 0.9973
# Epoch 99/100
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.0079 - acc: 0.9974
# Epoch 100/100
# 60000/60000 [==============================] - 3s 53us/step - loss: 0.0079 - acc: 0.9977
# Test score: 0.12291225457715546
# Test accuracy: 0.9808

# %%
model = Sequential()
model.add(Dense(800, input_shape=(784,)))
model.add(Activation ('relu'))
model.add(Dropout(.15))
model.add(Dense(100))
model.add(Activation ('relu'))
model.add(Dropout(.05))
model.add(Dense(50))
model.add(Activation ('relu'))

## Once you one-hot encode the data labels, the line below should be predicting probabilities of each of the 10 classes
## e.g. it should read: model.add(Dense(10)), not model.add(Dense(1))
model.add(Dense(10))
model.add(Activation('softmax'))

## Printing a summary of the layers and weights in your model
model.summary()

## In the line below we have specified the loss function as 'mse' (Mean Squared Error) because in the above code we did not one-hot encode the labels.
## In your implementation, since you are one-hot encoding the labels, you should use 'categorical_crossentropy' as your loss.
## You will likely have the best results with RMS prop or Adam as your optimizer.  In the line below we use Adadelta
model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])

fit = model.fit(X_train, y_train, batch_size=128, nb_epoch=10,
    verbose=1)

## Printing the accuracy of our model, according to the loss function specified in model.compile above
score = model.evaluate(X_test, y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_131 (Dense)            (None, 800)               628000
# _________________________________________________________________
# activation_126 (Activation)  (None, 800)               0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 800)               0
# _________________________________________________________________
# dense_132 (Dense)            (None, 100)               80100
# _________________________________________________________________
# activation_127 (Activation)  (None, 100)               0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_133 (Dense)            (None, 50)                5050
# _________________________________________________________________
# activation_128 (Activation)  (None, 50)                0
# _________________________________________________________________
# dense_134 (Dense)            (None, 10)                510
# _________________________________________________________________
# activation_129 (Activation)  (None, 10)                0
# =================================================================
# Total params: 713,660
# Trainable params: 713,660
# Non-trainable params: 0
# _________________________________________________________________
# /Users/eli/anaconda/lib/python3.6/site-packages/keras/models.py:944: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/10
# 60000/60000 [==============================] - 12s 200us/step - loss: 0.2600 - acc: 0.9228
# Epoch 2/10
# 60000/60000 [==============================] - 10s 170us/step - loss: 0.0999 - acc: 0.9688
# Epoch 3/10
#  - ETA: 2s - loss: 0.0700 - acc: 0.9776
# Epoch 4/10
#  - ETA: 9s - loss: 0.0455 - acc: 0.9870
# Epoch 5/10
# 60000/60000 [==============================] - 11s 183us/step - loss: 0.0432 - acc: 0.9868
# Epoch 6/10
# 60000/60000 [==============================] - 11s 186us/step - loss: 0.0347 - acc: 0.9889
# Epoch 7/10
# 60000/60000 [==============================] - 12s 202us/step - loss: 0.0294 - acc: 0.9900
# Epoch 8/10
# 60000/60000 [==============================] - 12s 207us/step - loss: 0.0252 - acc: 0.9917
# Epoch 9/10
#  - ETA: 6s - loss: 0.0217 - acc: 0.9931
# Epoch 10/10
# 60000/60000 [==============================] - 13s 210us/step - loss: 0.0225 - acc: 0.9925
# Test score: 0.0615268822472106
# Test accuracy: 0.9832
